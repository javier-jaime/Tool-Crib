# %% [markdown]
# <a href="https://colab.research.google.com/github/javier-jaime/Tool-Crib/blob/master/Neo4j/Spatial_Graph_visualization_with_networkx_and_matplotlib.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Spatial Graph Visualization with `networkx` and `matplotlib`

# %%
# install requirements
# !pip install networkx==3.0 matplotlib==3.6.3
# Out:
# Requirement already satisfied: networkx==3.0 in /usr/local/lib/python3.10/dist-packages (3.0)
# Requirement already satisfied: matplotlib==3.6.3 in /usr/local/lib/python3.10/dist-packages (3.6.3)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib==3.6.3) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib==3.6.3) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib==3.6.3) (4.44.3)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib==3.6.3) (1.4.5)
# Requirement already satisfied: numpy>=1.19 in /usr/local/lib/python3.10/dist-packages (from matplotlib==3.6.3) (1.23.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib==3.6.3) (23.2)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib==3.6.3) (9.4.0)
# Requirement already satisfied: pyparsing>=2.2.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib==3.6.3) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib==3.6.3) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib==3.6.3) (1.16.0)

# %%
import networkx as nx
nx.__version__
# Out:
# '3.0'

# %% [markdown]
# ## Manually creating a graph

# %%
G = nx.Graph()

# %%
G.add_node("A", size=1)
G.add_node("B", size=1)
G.add_node("C", size=1)
G.add_node("D", size=1)
G.add_node("E", size=1)

G.add_edge("A", "B", weight=1)
G.add_edge("A", "D", weight=1)

# %% [markdown]
# ## Reading graph data from file
#
# The `networkx` package also provides functionalities to read and write graphs from and to files, using different formats. In preceding chapters, we have used the `edgelist` format for instance, which can be handled using the following functions:
#
# - `G = nx.read_edgelist("path/to/file.edgelist")`
# - `nx.write_edgelist(G, "path/to/file.edgelist")`
#
# Same functions exist for dealing with `GraphML` file format:
#
# - `G = nx.read_graphml("path/to/file.edgelist")`
# - `nx.write_graphml(G, "path/to/file.edgelist")`
#
# Let's import some data. It is an extracted portion of Open Street Map data around the Colosseum in Rome.

# %%
G = nx.read_graphml("osm_street_network_rome.graphml")
G.number_of_nodes(), G.number_of_edges()
# Out:
# (1116, 2069)

# %%
# explore node data
list(G.nodes(data=True))[:10]
# Out:
# [('25388387', {'longitude': 12.4744851, 'latitude': 41.8964807}),
#  ('25388389', {'longitude': 12.4758502, 'latitude': 41.8963102}),
#  ('25418882', {'longitude': 12.4952304, 'latitude': 41.902029}),
#  ('25418884', {'longitude': 12.494543, 'latitude': 41.9015887}),
#  ('25418885', {'longitude': 12.4938275, 'latitude': 41.9011203}),
#  ('25418886', {'longitude': 12.4930978, 'latitude': 41.9006435}),
#  ('25418887', {'longitude': 12.492499, 'latitude': 41.9002394}),
#  ('25418888', {'longitude': 12.491662, 'latitude': 41.8996964}),
#  ('25418889', {'longitude': 12.4903418, 'latitude': 41.8988284}),
#  ('25418891', {'longitude': 12.4900226, 'latitude': 41.8986141})]

# %%
# define node position:
pos = {
    node_id: (node_data["longitude"], node_data["latitude"])
    for node_id, node_data in G.nodes(data=True)
}

# %%
nx.draw(G, pos=pos, node_size=10)
