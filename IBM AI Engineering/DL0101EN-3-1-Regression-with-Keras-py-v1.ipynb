# %% [markdown]
# <a href="https://cognitiveclass.ai"><img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DL0101EN-SkillsNetwork/images/IDSN-logo.png" width="400"> </a>
#
# # Regression Models with Keras
#
# Estimated time needed: **45** mins

# %% [markdown]
# ## Introduction

# %% [markdown]
# As we discussed in the videos, despite the popularity of more powerful libraries such as PyToch and TensorFlow, they are not easy to use and have a steep learning curve. So, for people who are just starting to learn deep learning, there is no better library to use other than the Keras library.
#
# Keras is a high-level API for building deep learning models. It has gained favor for its ease of use and syntactic simplicity facilitating fast development. As you will see in this lab and the other labs in this course, building a very complex deep learning network can be achieved with Keras with only few lines of code. You will appreciate Keras even more, once you learn how to build deep models using PyTorch and TensorFlow in the other courses.
#
# So, in this lab, you will learn how to use the Keras library to build a regression model.

# %% [markdown]
# ## Objectives for this Notebook
# * How to use the Keras library to build a regression model
# * Download and clean the data set
# * Build a neural network
# * Train and test the network

# %% [markdown]
# <h2>Table of Contents</h2>
#
#
# <div class="alert alert-block alert-info" style="margin-top: 20px">
#
# <font size = 4>
# 1. <a href="#Download-and-Clean-the-Data-Set">Download and Clean the Data Set</a><br>
# 2. <a href="#Import-Keras-Packages">Import Keras Packages</a><br>
# 3. <a href="#Build-a-Neural-Network">Build a Neural Network</a><br>
# 4. <a href="#Train-and-Test-the-Network">Train and Test the Network</a><br>
#
# </font>
# </div>

# %% [markdown]
# Let's start by importing the <em>pandas</em> and the Numpy libraries.

# %%
# All Libraries required for this lab are listed below. 

# !pip install numpy==2.0.2
# !pip install pandas==2.2.2
# !pip install tensorflow_cpu==2.18.0
# Out:
# Collecting numpy==2.0.2
#   Downloading numpy-2.0.2-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (60 kB)
# Downloading numpy-2.0.2-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (19.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 19.2/19.2 MB 123.4 MB/s eta 0:00:00
# Installing collected packages: numpy
# Successfully installed numpy-2.0.2
# Collecting pandas==2.2.2
#   Downloading pandas-2.2.2-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (19 kB)
# Requirement already satisfied: numpy>=1.26.0 in /opt/conda/lib/python3.12/site-packages (from pandas==2.2.2) (2.0.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/conda/lib/python3.12/site-packages (from pandas==2.2.2) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /opt/conda/lib/python3.12/site-packages (from pandas==2.2.2) (2024.2)
# Collecting tzdata>=2022.7 (from pandas==2.2.2)
#   Downloading tzdata-2025.2-py2.py3-none-any.whl.metadata (1.4 kB)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.12/site-packages (from python-dateutil>=2.8.2->pandas==2.2.2) (1.17.0)
# Downloading pandas-2.2.2-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (12.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.7/12.7 MB 125.5 MB/s eta 0:00:00
# Downloading tzdata-2025.2-py2.py3-none-any.whl (347 kB)
# Installing collected packages: tzdata, pandas
# Successfully installed pandas-2.2.2 tzdata-2025.2
# Collecting tensorflow_cpu==2.18.0
#   Downloading tensorflow_cpu-2.18.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.1 kB)
# Collecting absl-py>=1.0.0 (from tensorflow_cpu==2.18.0)
#   Downloading absl_py-2.3.1-py3-none-any.whl.metadata (3.3 kB)
# Collecting astunparse>=1.6.0 (from tensorflow_cpu==2.18.0)
#   Downloading astunparse-1.6.3-py2.py3-none-any.whl.metadata (4.4 kB)
# Collecting flatbuffers>=24.3.25 (from tensorflow_cpu==2.18.0)
#   Downloading flatbuffers-25.9.23-py2.py3-none-any.whl.metadata (875 bytes)
# Collecting gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 (from tensorflow_cpu==2.18.0)
#   Downloading gast-0.6.0-py3-none-any.whl.metadata (1.3 kB)
# Collecting google-pasta>=0.1.1 (from tensorflow_cpu==2.18.0)
#   Downloading google_pasta-0.2.0-py3-none-any.whl.metadata (814 bytes)
# Collecting libclang>=13.0.0 (from tensorflow_cpu==2.18.0)
#   Downloading libclang-18.1.1-py2.py3-none-manylinux2010_x86_64.whl.metadata (5.2 kB)
# Collecting opt-einsum>=2.3.2 (from tensorflow_cpu==2.18.0)
#   Downloading opt_einsum-3.4.0-py3-none-any.whl.metadata (6.3 kB)
# Requirement already satisfied: packaging in /opt/conda/lib/python3.12/site-packages (from tensorflow_cpu==2.18.0) (24.2)
# Collecting protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0dev,>=3.20.3 (from tensorflow_cpu==2.18.0)
#   Downloading protobuf-5.29.5-cp38-abi3-manylinux2014_x86_64.whl.metadata (592 bytes)
# Requirement already satisfied: requests<3,>=2.21.0 in /opt/conda/lib/python3.12/site-packages (from tensorflow_cpu==2.18.0) (2.32.3)
# Requirement already satisfied: setuptools in /opt/conda/lib/python3.12/site-packages (from tensorflow_cpu==2.18.0) (75.8.0)
# Requirement already satisfied: six>=1.12.0 in /opt/conda/lib/python3.12/site-packages (from tensorflow_cpu==2.18.0) (1.17.0)
# Collecting termcolor>=1.1.0 (from tensorflow_cpu==2.18.0)
#   Downloading termcolor-3.1.0-py3-none-any.whl.metadata (6.4 kB)
# Requirement already satisfied: typing-extensions>=3.6.6 in /opt/conda/lib/python3.12/site-packages (from tensorflow_cpu==2.18.0) (4.12.2)
# Collecting wrapt>=1.11.0 (from tensorflow_cpu==2.18.0)
#   Downloading wrapt-1.17.3-cp312-cp312-manylinux1_x86_64.manylinux_2_28_x86_64.manylinux_2_5_x86_64.whl.metadata (6.4 kB)
# Collecting grpcio<2.0,>=1.24.3 (from tensorflow_cpu==2.18.0)
#   Downloading grpcio-1.75.1-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (3.7 kB)
# Collecting tensorboard<2.19,>=2.18 (from tensorflow_cpu==2.18.0)
#   Downloading tensorboard-2.18.0-py3-none-any.whl.metadata (1.6 kB)
# Collecting keras>=3.5.0 (from tensorflow_cpu==2.18.0)
#   Downloading keras-3.11.3-py3-none-any.whl.metadata (5.9 kB)
# Requirement already satisfied: numpy<2.1.0,>=1.26.0 in /opt/conda/lib/python3.12/site-packages (from tensorflow_cpu==2.18.0) (2.0.2)
# Collecting h5py>=3.11.0 (from tensorflow_cpu==2.18.0)
#   Downloading h5py-3.14.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (2.7 kB)
# Collecting ml-dtypes<0.5.0,>=0.4.0 (from tensorflow_cpu==2.18.0)
#   Downloading ml_dtypes-0.4.1-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (20 kB)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /opt/conda/lib/python3.12/site-packages (from astunparse>=1.6.0->tensorflow_cpu==2.18.0) (0.45.1)
# Collecting rich (from keras>=3.5.0->tensorflow_cpu==2.18.0)
#   Downloading rich-14.2.0-py3-none-any.whl.metadata (18 kB)
# Collecting namex (from keras>=3.5.0->tensorflow_cpu==2.18.0)
#   Downloading namex-0.1.0-py3-none-any.whl.metadata (322 bytes)
# Collecting optree (from keras>=3.5.0->tensorflow_cpu==2.18.0)
#   Downloading optree-0.17.0-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (33 kB)
# Requirement already satisfied: charset_normalizer<4,>=2 in /opt/conda/lib/python3.12/site-packages (from requests<3,>=2.21.0->tensorflow_cpu==2.18.0) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.12/site-packages (from requests<3,>=2.21.0->tensorflow_cpu==2.18.0) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.12/site-packages (from requests<3,>=2.21.0->tensorflow_cpu==2.18.0) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.12/site-packages (from requests<3,>=2.21.0->tensorflow_cpu==2.18.0) (2024.12.14)
# Collecting markdown>=2.6.8 (from tensorboard<2.19,>=2.18->tensorflow_cpu==2.18.0)
#   Downloading markdown-3.9-py3-none-any.whl.metadata (5.1 kB)
# Collecting tensorboard-data-server<0.8.0,>=0.7.0 (from tensorboard<2.19,>=2.18->tensorflow_cpu==2.18.0)
#   Downloading tensorboard_data_server-0.7.2-py3-none-manylinux_2_31_x86_64.whl.metadata (1.1 kB)
# Collecting werkzeug>=1.0.1 (from tensorboard<2.19,>=2.18->tensorflow_cpu==2.18.0)
#   Downloading werkzeug-3.1.3-py3-none-any.whl.metadata (3.7 kB)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /opt/conda/lib/python3.12/site-packages (from werkzeug>=1.0.1->tensorboard<2.19,>=2.18->tensorflow_cpu==2.18.0) (3.0.2)
# Collecting markdown-it-py>=2.2.0 (from rich->keras>=3.5.0->tensorflow_cpu==2.18.0)
#   Downloading markdown_it_py-4.0.0-py3-none-any.whl.metadata (7.3 kB)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /opt/conda/lib/python3.12/site-packages (from rich->keras>=3.5.0->tensorflow_cpu==2.18.0) (2.19.1)
# Collecting mdurl~=0.1 (from markdown-it-py>=2.2.0->rich->keras>=3.5.0->tensorflow_cpu==2.18.0)
#   Downloading mdurl-0.1.2-py3-none-any.whl.metadata (1.6 kB)
# Downloading tensorflow_cpu-2.18.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (230.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 230.3/230.3 MB 41.6 MB/s eta 0:00:0000:0100:01
# Downloading absl_py-2.3.1-py3-none-any.whl (135 kB)
# Downloading astunparse-1.6.3-py2.py3-none-any.whl (12 kB)
# Downloading flatbuffers-25.9.23-py2.py3-none-any.whl (30 kB)
# Downloading gast-0.6.0-py3-none-any.whl (21 kB)
# Downloading google_pasta-0.2.0-py3-none-any.whl (57 kB)
# Downloading grpcio-1.75.1-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (6.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.4/6.4 MB 142.1 MB/s eta 0:00:00
# Downloading h5py-3.14.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (4.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.9/4.9 MB 56.0 MB/s eta 0:00:00
# Downloading keras-3.11.3-py3-none-any.whl (1.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 51.0 MB/s eta 0:00:00
# Downloading libclang-18.1.1-py2.py3-none-manylinux2010_x86_64.whl (24.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.5/24.5 MB 46.8 MB/s eta 0:00:00:00:01
# Downloading ml_dtypes-0.4.1-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 52.6 MB/s eta 0:00:00
# Downloading opt_einsum-3.4.0-py3-none-any.whl (71 kB)
# Downloading protobuf-5.29.5-cp38-abi3-manylinux2014_x86_64.whl (319 kB)
# Downloading tensorboard-2.18.0-py3-none-any.whl (5.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.5/5.5 MB 59.8 MB/s eta 0:00:00
# Downloading termcolor-3.1.0-py3-none-any.whl (7.7 kB)
# Downloading wrapt-1.17.3-cp312-cp312-manylinux1_x86_64.manylinux_2_28_x86_64.manylinux_2_5_x86_64.whl (88 kB)
# Downloading markdown-3.9-py3-none-any.whl (107 kB)
# Downloading tensorboard_data_server-0.7.2-py3-none-manylinux_2_31_x86_64.whl (6.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.6/6.6 MB 54.8 MB/s eta 0:00:00
# Downloading werkzeug-3.1.3-py3-none-any.whl (224 kB)
# Downloading namex-0.1.0-py3-none-any.whl (5.9 kB)
# Downloading optree-0.17.0-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (408 kB)
# Downloading rich-14.2.0-py3-none-any.whl (243 kB)
# Downloading markdown_it_py-4.0.0-py3-none-any.whl (87 kB)
# Downloading mdurl-0.1.2-py3-none-any.whl (10.0 kB)
# Installing collected packages: namex, libclang, flatbuffers, wrapt, werkzeug, termcolor, tensorboard-data-server, protobuf, optree, opt-einsum, ml-dtypes, mdurl, markdown, h5py, grpcio, google-pasta, gast, astunparse, absl-py, tensorboard, markdown-it-py, rich, keras, tensorflow_cpu
# Successfully installed absl-py-2.3.1 astunparse-1.6.3 flatbuffers-25.9.23 gast-0.6.0 google-pasta-0.2.0 grpcio-1.75.1 h5py-3.14.0 keras-3.11.3 libclang-18.1.1 markdown-3.9 markdown-it-py-4.0.0 mdurl-0.1.2 ml-dtypes-0.4.1 namex-0.1.0 opt-einsum-3.4.0 optree-0.17.0 protobuf-5.29.5 rich-14.2.0 tensorboard-2.18.0 tensorboard-data-server-0.7.2 tensorflow_cpu-2.18.0 termcolor-3.1.0 werkzeug-3.1.3 wrapt-1.17.3

# %% [markdown]
# #### To use Keras, you will also need to install a backend framework – such as TensorFlow.
#
# If you install TensorFlow 2.16 or above, it will install Keras by default.
#
# We are using the CPU version of tensorflow since we are dealing with smaller datasets.
# You may install the GPU version of tensorflow on your machine to accelarate the processing of larger datasets

# %% [markdown]
# #### Suppress the tensorflow warning messages
# We use the following code to  suppress the warning messages due to use of CPU architechture for tensoflow.
#
# You may want to **comment out** these lines if you are using the GPU architechture

# %%
import os
os.environ['TF_ENABLE_ONEDNN_OPTS'] = '0'
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '2'

# %%
import pandas as pd
import numpy as np
import keras

import warnings
warnings.simplefilter('ignore', FutureWarning)

# %% [markdown]
# We will be playing around with the same dataset that we used in the videos.
#
# <strong>The dataset is about the compressive strength of different samples of concrete based on the volumes of the different ingredients that were used to make them. Ingredients include:</strong>
#
# * Cement
# * Blast furnace slag
# * Fly ash
# * Water
# * Superplasticizer
# * Coarse aggregate
# * Fine aggregate

# %% [markdown]
# ## Download and Clean the Data Set

# %% [markdown]
# Let's download the data and read it into a <em>pandas</em> dataframe.

# %%
filepath='https://s3-api.us-geo.objectstorage.softlayer.net/cf-courses-data/CognitiveClass/DL0101EN/labs/data/concrete_data.csv'
concrete_data = pd.read_csv(filepath)

concrete_data.head()
# Out:
#    Cement  Blast Furnace Slag  Fly Ash  Water  Superplasticizer  \
# 0   540.0                 0.0      0.0  162.0               2.5
# 1   540.0                 0.0      0.0  162.0               2.5
# 2   332.5               142.5      0.0  228.0               0.0
# 3   332.5               142.5      0.0  228.0               0.0
# 4   198.6               132.4      0.0  192.0               0.0
#
#    Coarse Aggregate  Fine Aggregate  Age  Strength
# 0            1040.0           676.0   28     79.99
# 1            1055.0           676.0   28     61.89
# 2             932.0           594.0  270     40.27
# 3             932.0           594.0  365     41.05
# 4             978.4           825.5  360     44.30

# %% [markdown]
# So the first concrete sample has 540 cubic meter of cement, 0 cubic meter of blast furnace slag, 0 cubic meter of fly ash, 162 cubic meter of water, 2.5 cubic meter of superplaticizer, 1040 cubic meter of coarse aggregate, 676 cubic meter of fine aggregate. Such a concrete mix which is 28 days old, has a compressive strength of 79.99 MPa.

# %% [markdown]
# #### Let's check how many data points we have

# %%
concrete_data.shape
# Out:
# (1030, 9)

# %% [markdown]
# So, there are approximately 1000 samples to train our model on. Because of the few samples, we have to be careful not to overfit the training data.

# %% [markdown]
# Let's check the dataset for any missing values.

# %%
concrete_data.describe()
# Out:
#             Cement  Blast Furnace Slag      Fly Ash        Water  \
# count  1030.000000         1030.000000  1030.000000  1030.000000
# mean    281.167864           73.895825    54.188350   181.567282
# std     104.506364           86.279342    63.997004    21.354219
# min     102.000000            0.000000     0.000000   121.800000
# 25%     192.375000            0.000000     0.000000   164.900000
# 50%     272.900000           22.000000     0.000000   185.000000
# 75%     350.000000          142.950000   118.300000   192.000000
# max     540.000000          359.400000   200.100000   247.000000
#
#        Superplasticizer  Coarse Aggregate  Fine Aggregate          Age  \
# count       1030.000000       1030.000000     1030.000000  1030.000000
# mean           6.204660        972.918932      773.580485    45.662136
# std            5.973841         77.753954       80.175980    63.169912
# min            0.000000        801.000000      594.000000     1.000000
# 25%            0.000000        932.000000      730.950000     7.000000
# 50%            6.400000        968.000000      779.500000    28.000000
# 75%           10.200000       1029.400000      824.000000    56.000000
# max           32.200000       1145.000000      992.600000   365.000000
#
#           Strength
# count  1030.000000
# mean     35.817961
# std      16.705742
# min       2.330000
# 25%      23.710000
# 50%      34.445000
# 75%      46.135000
# max      82.600000

# %%
concrete_data.isnull().sum()
# Out:
# Cement                0
# Blast Furnace Slag    0
# Fly Ash               0
# Water                 0
# Superplasticizer      0
# Coarse Aggregate      0
# Fine Aggregate        0
# Age                   0
# Strength              0
# dtype: int64

# %% [markdown]
# The data looks very clean and is ready to be used to build our model.

# %% [markdown]
# #### Split data into predictors and target

# %% [markdown]
# The target variable in this problem is the concrete sample strength. Therefore, our predictors will be all the other columns.

# %%
concrete_data_columns = concrete_data.columns

# %%
predictors = concrete_data[concrete_data_columns[concrete_data_columns != 'Strength']] # all columns except Strength
target = concrete_data['Strength'] # Strength column

# %% [markdown]
# <a id="item2"></a>

# %% [markdown]
# Let's do a quick sanity check of the predictors and the target dataframes.

# %%
predictors.head()
# Out:
#    Cement  Blast Furnace Slag  Fly Ash  Water  Superplasticizer  \
# 0   540.0                 0.0      0.0  162.0               2.5
# 1   540.0                 0.0      0.0  162.0               2.5
# 2   332.5               142.5      0.0  228.0               0.0
# 3   332.5               142.5      0.0  228.0               0.0
# 4   198.6               132.4      0.0  192.0               0.0
#
#    Coarse Aggregate  Fine Aggregate  Age
# 0            1040.0           676.0   28
# 1            1055.0           676.0   28
# 2             932.0           594.0  270
# 3             932.0           594.0  365
# 4             978.4           825.5  360

# %%
target.head()
# Out:
# 0    79.99
# 1    61.89
# 2    40.27
# 3    41.05
# 4    44.30
# Name: Strength, dtype: float64

# %% [markdown]
# Finally, the last step is to normalize the data by substracting the mean and dividing by the standard deviation.

# %%
predictors_norm = (predictors - predictors.mean()) / predictors.std()
predictors_norm.head()
# Out:
#      Cement  Blast Furnace Slag   Fly Ash     Water  Superplasticizer  \
# 0  2.476712           -0.856472 -0.846733 -0.916319         -0.620147
# 1  2.476712           -0.856472 -0.846733 -0.916319         -0.620147
# 2  0.491187            0.795140 -0.846733  2.174405         -1.038638
# 3  0.491187            0.795140 -0.846733  2.174405         -1.038638
# 4 -0.790075            0.678079 -0.846733  0.488555         -1.038638
#
#    Coarse Aggregate  Fine Aggregate       Age
# 0          0.862735       -1.217079 -0.279597
# 1          1.055651       -1.217079 -0.279597
# 2         -0.526262       -2.239829  3.551340
# 3         -0.526262       -2.239829  5.055221
# 4          0.070492        0.647569  4.976069

# %% [markdown]
# Let's save the number of predictors to *n_cols* since we will need this number when building our network.

# %%
n_cols = predictors_norm.shape[1] # number of predictors

# %% [markdown]
# <a id="item1"></a>

# %% [markdown]
# ##  Import Keras Packages
#
# ##### Let's import the rest of the packages from the Keras library that we will need to build our regression model.

# %%
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import Input

# %% [markdown]
# ## Build a Neural Network

# %% [markdown]
# Let's define a function that defines our regression model for us so that we can conveniently call it to create our model.

# %%
# define regression model
def regression_model():
    # create model
    model = Sequential()
    model.add(Input(shape=(n_cols,)))
    model.add(Dense(50, activation='relu'))
    model.add(Dense(50, activation='relu'))
    model.add(Dense(1))
    
    # compile model
    model.compile(optimizer='adam', loss='mean_squared_error')
    return model

# %% [markdown]
# The above function create a model that has two hidden layers, each of 50 hidden units.

# %% [markdown]
# ## Train and Test the Network

# %% [markdown]
# Let's call the function now to create our model.

# %%
# build the model
model = regression_model()

# %% [markdown]
# Next, we will train and test the model at the same time using the *fit* method. We will leave out 30% of the data for validation and we will train the model for 100 epochs.

# %%
# fit the model
model.fit(predictors_norm, target, validation_split=0.3, epochs=100, verbose=2)
# Out:
# Epoch 1/100
# 23/23 - 1s - 48ms/step - loss: 1654.3907 - val_loss: 1154.3300
# Epoch 2/100
# 23/23 - 0s - 9ms/step - loss: 1529.0718 - val_loss: 1035.2487
# Epoch 3/100
# 23/23 - 0s - 7ms/step - loss: 1309.0065 - val_loss: 837.3632
# Epoch 4/100
# 23/23 - 0s - 8ms/step - loss: 972.3142 - val_loss: 572.1231
# Epoch 5/100
# 23/23 - 0s - 7ms/step - loss: 588.7344 - val_loss: 335.2609
# Epoch 6/100
# 23/23 - 0s - 6ms/step - loss: 322.3737 - val_loss: 217.4628
# Epoch 7/100
# 23/23 - 0s - 7ms/step - loss: 241.5843 - val_loss: 194.9131
# Epoch 8/100
# 23/23 - 0s - 6ms/step - loss: 223.2322 - val_loss: 193.0712
# Epoch 9/100
# 23/23 - 0s - 7ms/step - loss: 209.8562 - val_loss: 184.2465
# Epoch 10/100
# 23/23 - 0s - 6ms/step - loss: 199.7355 - val_loss: 180.5193
# Epoch 11/100
# 23/23 - 0s - 6ms/step - loss: 191.5584 - val_loss: 173.9975
# Epoch 12/100
# 23/23 - 0s - 6ms/step - loss: 184.3210 - val_loss: 171.7862
# Epoch 13/100
# 23/23 - 0s - 6ms/step - loss: 179.7705 - val_loss: 166.3358
# Epoch 14/100
# 23/23 - 0s - 7ms/step - loss: 173.9922 - val_loss: 164.8086
# Epoch 15/100
# 23/23 - 0s - 6ms/step - loss: 169.5553 - val_loss: 161.9125
# Epoch 16/100
# 23/23 - 0s - 6ms/step - loss: 165.2371 - val_loss: 157.0698
# Epoch 17/100
# 23/23 - 0s - 7ms/step - loss: 162.0347 - val_loss: 159.6990
# Epoch 18/100
# 23/23 - 0s - 6ms/step - loss: 158.7986 - val_loss: 155.4733
# Epoch 19/100
# 23/23 - 0s - 6ms/step - loss: 155.7685 - val_loss: 155.0746
# Epoch 20/100
# 23/23 - 0s - 7ms/step - loss: 153.0938 - val_loss: 152.5300
# Epoch 21/100
# 23/23 - 0s - 7ms/step - loss: 150.9525 - val_loss: 152.2091
# Epoch 22/100
# 23/23 - 0s - 7ms/step - loss: 148.8004 - val_loss: 151.3209
# Epoch 23/100
# 23/23 - 0s - 6ms/step - loss: 146.9650 - val_loss: 148.6201
# Epoch 24/100
# 23/23 - 0s - 7ms/step - loss: 145.5970 - val_loss: 148.1786
# Epoch 25/100
# 23/23 - 0s - 6ms/step - loss: 143.3154 - val_loss: 147.3274
# Epoch 26/100
# 23/23 - 0s - 6ms/step - loss: 142.7641 - val_loss: 146.3197
# Epoch 27/100
# 23/23 - 0s - 6ms/step - loss: 140.5093 - val_loss: 147.0847
# Epoch 28/100
# 23/23 - 0s - 6ms/step - loss: 138.9651 - val_loss: 145.1012
# Epoch 29/100
# 23/23 - 0s - 6ms/step - loss: 137.1628 - val_loss: 144.3940
# Epoch 30/100
# 23/23 - 0s - 7ms/step - loss: 136.0686 - val_loss: 144.2274
# Epoch 31/100
# 23/23 - 0s - 6ms/step - loss: 134.7840 - val_loss: 143.2849
# Epoch 32/100
# 23/23 - 0s - 6ms/step - loss: 133.7383 - val_loss: 142.0206
# Epoch 33/100
# 23/23 - 0s - 6ms/step - loss: 132.2669 - val_loss: 143.1229
# Epoch 34/100
# 23/23 - 0s - 6ms/step - loss: 131.0054 - val_loss: 139.5364
# Epoch 35/100
# 23/23 - 0s - 7ms/step - loss: 129.5835 - val_loss: 141.6538
# Epoch 36/100
# 23/23 - 0s - 7ms/step - loss: 128.6709 - val_loss: 139.5142
# Epoch 37/100
# 23/23 - 0s - 7ms/step - loss: 127.2099 - val_loss: 141.1270
# Epoch 38/100
# 23/23 - 0s - 6ms/step - loss: 125.5709 - val_loss: 138.0253
# Epoch 39/100
# 23/23 - 0s - 6ms/step - loss: 124.4083 - val_loss: 137.5689
# Epoch 40/100
# 23/23 - 0s - 6ms/step - loss: 123.2839 - val_loss: 135.1644
# Epoch 41/100
# 23/23 - 0s - 6ms/step - loss: 122.2645 - val_loss: 138.4135
# Epoch 42/100
# 23/23 - 0s - 6ms/step - loss: 121.2544 - val_loss: 134.9055
# Epoch 43/100
# 23/23 - 0s - 7ms/step - loss: 118.9543 - val_loss: 135.8083
# Epoch 44/100
# 23/23 - 0s - 7ms/step - loss: 117.5057 - val_loss: 132.2548
# Epoch 45/100
# 23/23 - 0s - 7ms/step - loss: 115.6856 - val_loss: 132.9611
# Epoch 46/100
# 23/23 - 0s - 7ms/step - loss: 113.7867 - val_loss: 131.2449
# Epoch 47/100
# 23/23 - 0s - 7ms/step - loss: 112.2163 - val_loss: 130.8831
# Epoch 48/100
# 23/23 - 0s - 7ms/step - loss: 110.8747 - val_loss: 129.3118
# Epoch 49/100
# 23/23 - 0s - 6ms/step - loss: 110.2210 - val_loss: 130.5126
# Epoch 50/100
# 23/23 - 0s - 6ms/step - loss: 107.6940 - val_loss: 126.2852
# Epoch 51/100
# 23/23 - 0s - 6ms/step - loss: 104.3971 - val_loss: 129.4409
# Epoch 52/100
# 23/23 - 0s - 6ms/step - loss: 103.2637 - val_loss: 129.4384
# Epoch 53/100
# 23/23 - 0s - 6ms/step - loss: 100.4363 - val_loss: 126.6945
# Epoch 54/100
# 23/23 - 0s - 6ms/step - loss: 98.1493 - val_loss: 122.2383
# Epoch 55/100
# 23/23 - 0s - 6ms/step - loss: 96.2542 - val_loss: 125.5413
# Epoch 56/100
# 23/23 - 0s - 6ms/step - loss: 93.0970 - val_loss: 122.5660
# Epoch 57/100
# 23/23 - 0s - 6ms/step - loss: 90.6157 - val_loss: 123.9498
# Epoch 58/100
# 23/23 - 0s - 6ms/step - loss: 88.2563 - val_loss: 120.7884
# Epoch 59/100
# 23/23 - 0s - 6ms/step - loss: 86.4548 - val_loss: 120.3557
# Epoch 60/100
# 23/23 - 0s - 6ms/step - loss: 83.6398 - val_loss: 116.1051
# Epoch 61/100
# 23/23 - 0s - 6ms/step - loss: 81.0757 - val_loss: 118.2505
# Epoch 62/100
# 23/23 - 0s - 6ms/step - loss: 79.0060 - val_loss: 114.8239
# Epoch 63/100
# 23/23 - 0s - 6ms/step - loss: 76.3968 - val_loss: 115.7104
# Epoch 64/100
# 23/23 - 0s - 6ms/step - loss: 74.3321 - val_loss: 112.3326
# Epoch 65/100
# 23/23 - 0s - 6ms/step - loss: 72.1127 - val_loss: 112.8473
# Epoch 66/100
# 23/23 - 0s - 6ms/step - loss: 70.2331 - val_loss: 110.6115
# Epoch 67/100
# 23/23 - 0s - 6ms/step - loss: 68.0754 - val_loss: 107.9322
# Epoch 68/100
# 23/23 - 0s - 6ms/step - loss: 66.3512 - val_loss: 109.9543
# Epoch 69/100
# 23/23 - 0s - 7ms/step - loss: 65.3228 - val_loss: 105.2945
# Epoch 70/100
# 23/23 - 0s - 6ms/step - loss: 64.0975 - val_loss: 105.9527
# Epoch 71/100
# 23/23 - 0s - 6ms/step - loss: 61.6357 - val_loss: 109.2820
# Epoch 72/100
# 23/23 - 0s - 6ms/step - loss: 60.2065 - val_loss: 101.7336
# Epoch 73/100
# 23/23 - 0s - 6ms/step - loss: 59.0022 - val_loss: 104.0623
# Epoch 74/100
# 23/23 - 0s - 7ms/step - loss: 57.4067 - val_loss: 103.0491
# Epoch 75/100
# 23/23 - 0s - 7ms/step - loss: 56.2313 - val_loss: 104.3856
# Epoch 76/100
# 23/23 - 0s - 6ms/step - loss: 56.2583 - val_loss: 99.1043
# Epoch 77/100
# 23/23 - 0s - 6ms/step - loss: 54.2434 - val_loss: 110.1379
# Epoch 78/100
# 23/23 - 0s - 6ms/step - loss: 52.7862 - val_loss: 100.6547
# Epoch 79/100
# 23/23 - 0s - 6ms/step - loss: 51.3305 - val_loss: 104.8161
# Epoch 80/100
# 23/23 - 0s - 6ms/step - loss: 50.2144 - val_loss: 101.4971
# Epoch 81/100
# 23/23 - 0s - 6ms/step - loss: 49.2076 - val_loss: 100.6992
# Epoch 82/100
# 23/23 - 0s - 6ms/step - loss: 47.9085 - val_loss: 106.1727
# Epoch 83/100
# 23/23 - 0s - 6ms/step - loss: 46.3368 - val_loss: 109.6242
# Epoch 84/100
# 23/23 - 0s - 6ms/step - loss: 45.3044 - val_loss: 102.9441
# Epoch 85/100
# 23/23 - 0s - 6ms/step - loss: 43.8918 - val_loss: 113.6933
# Epoch 86/100
# 23/23 - 0s - 6ms/step - loss: 43.1064 - val_loss: 103.4382
# Epoch 87/100
# 23/23 - 0s - 7ms/step - loss: 42.3168 - val_loss: 115.4678
# Epoch 88/100
# 23/23 - 0s - 6ms/step - loss: 41.6657 - val_loss: 105.2986
# Epoch 89/100
# 23/23 - 0s - 6ms/step - loss: 40.8689 - val_loss: 107.7716
# Epoch 90/100
# 23/23 - 0s - 7ms/step - loss: 39.9809 - val_loss: 113.8147
# Epoch 91/100
# 23/23 - 0s - 6ms/step - loss: 39.9507 - val_loss: 114.1873
# Epoch 92/100
# 23/23 - 0s - 6ms/step - loss: 38.9282 - val_loss: 119.3804
# Epoch 93/100
# 23/23 - 0s - 6ms/step - loss: 38.9872 - val_loss: 120.2794
# Epoch 94/100
# 23/23 - 0s - 6ms/step - loss: 38.2704 - val_loss: 116.8514
# Epoch 95/100
# 23/23 - 0s - 7ms/step - loss: 37.9102 - val_loss: 118.4167
# Epoch 96/100
# 23/23 - 0s - 6ms/step - loss: 37.2365 - val_loss: 111.0882
# Epoch 97/100
# 23/23 - 0s - 6ms/step - loss: 36.5986 - val_loss: 116.2162
# Epoch 98/100
# 23/23 - 0s - 6ms/step - loss: 35.7341 - val_loss: 125.3004
# Epoch 99/100
# 23/23 - 0s - 7ms/step - loss: 35.3118 - val_loss: 119.2226
# Epoch 100/100
# 23/23 - 0s - 7ms/step - loss: 35.8373 - val_loss: 127.2347

# %% [markdown]
# <strong>You can refer to this [link](https://keras.io/models/sequential/) to learn about other functions that you can use for prediction or evaluation.</strong>

# %% [markdown]
# Feel free to vary the following and note what impact each change has on the model's performance:
#
# 1. Increase or decreate number of neurons in hidden layers
# 2. Add more hidden layers
# 3. Increase number of epochs

# %% [markdown]
# <h3>Practice Exercise 1</h3>

# %% [markdown]
# Now using the same dateset,try to recreate regression model featuring five hidden layers, each with 50 nodes and ReLU activation functions, a single output layer, optimized using the Adam optimizer.

# %%
# Write your code here
def regression_model():
    input_colm = predictors_norm.shape[1] # Number of input features
    # create model
    model = Sequential()
    model.add(Input(shape=(input_colm,)))  # Set the number of input features 
    model.add(Dense(50, activation='relu'))  
    model.add(Dense(50, activation='relu'))
    model.add(Dense(50, activation='relu')) 
    model.add(Dense(50, activation='relu'))
    model.add(Dense(50, activation='relu'))  
    model.add(Dense(1))  # Output layer
    
    # compile model
    model.compile(optimizer='adam', loss='mean_squared_error')
    return model

# %% [markdown]
# Double-click <b>here</b> for the solution.
#
# <!-- Your answer is below:
# def regression_model():
#     input_colm = predictors_norm.shape[1] # Number of input features
#     # create model
#     model = Sequential()
#     model.add(Input(shape=(input_colm,)))  # Set the number of input features
#     model.add(Dense(50, activation='relu'))
#     model.add(Dense(50, activation='relu'))
#     model.add(Dense(50, activation='relu'))
#     model.add(Dense(50, activation='relu'))
#     model.add(Dense(50, activation='relu'))
#     model.add(Dense(1))  # Output layer
#
#     # compile model
#     model.compile(optimizer='adam', loss='mean_squared_error')
#     return model
#
# -->

# %% [markdown]
# <h3>Practice Exercise 2</h3>

# %% [markdown]
#  Train and evaluate the model simultaneously using the fit() method by reserving 10% of the data for validation and training the model for 100 epochs

# %%
# Write your code here
# build the model
model = regression_model()
model.fit(predictors_norm, target, validation_split=0.1, epochs=100, verbose=2)
# Out:
# Epoch 1/100
# 29/29 - 2s - 65ms/step - loss: 1494.9783 - val_loss: 909.6693
# Epoch 2/100
# 29/29 - 0s - 8ms/step - loss: 624.8313 - val_loss: 219.2862
# Epoch 3/100
# 29/29 - 0s - 8ms/step - loss: 237.8008 - val_loss: 190.1008
# Epoch 4/100
# 29/29 - 0s - 7ms/step - loss: 205.4756 - val_loss: 174.7941
# Epoch 5/100
# 29/29 - 0s - 7ms/step - loss: 185.7005 - val_loss: 168.4145
# Epoch 6/100
# 29/29 - 0s - 6ms/step - loss: 169.9588 - val_loss: 160.6538
# Epoch 7/100
# 29/29 - 0s - 6ms/step - loss: 154.6031 - val_loss: 154.3976
# Epoch 8/100
# 29/29 - 0s - 7ms/step - loss: 142.2739 - val_loss: 150.3503
# Epoch 9/100
# 29/29 - 0s - 7ms/step - loss: 131.1952 - val_loss: 144.2979
# Epoch 10/100
# 29/29 - 0s - 7ms/step - loss: 116.5395 - val_loss: 141.2921
# Epoch 11/100
# 29/29 - 0s - 6ms/step - loss: 101.2669 - val_loss: 137.9566
# Epoch 12/100
# 29/29 - 0s - 6ms/step - loss: 88.5949 - val_loss: 124.2358
# Epoch 13/100
# 29/29 - 0s - 6ms/step - loss: 77.8213 - val_loss: 111.6086
# Epoch 14/100
# 29/29 - 0s - 6ms/step - loss: 65.2641 - val_loss: 100.8830
# Epoch 15/100
# 29/29 - 0s - 7ms/step - loss: 58.6063 - val_loss: 91.9509
# Epoch 16/100
# 29/29 - 0s - 6ms/step - loss: 52.2749 - val_loss: 88.8707
# Epoch 17/100
# 29/29 - 0s - 6ms/step - loss: 47.7362 - val_loss: 86.3927
# Epoch 18/100
# 29/29 - 0s - 7ms/step - loss: 44.5281 - val_loss: 67.0619
# Epoch 19/100
# 29/29 - 0s - 8ms/step - loss: 41.9026 - val_loss: 66.5745
# Epoch 20/100
# 29/29 - 0s - 6ms/step - loss: 39.5221 - val_loss: 59.1690
# Epoch 21/100
# 29/29 - 0s - 6ms/step - loss: 35.7205 - val_loss: 60.6845
# Epoch 22/100
# 29/29 - 0s - 6ms/step - loss: 33.5165 - val_loss: 46.2566
# Epoch 23/100
# 29/29 - 0s - 6ms/step - loss: 31.5233 - val_loss: 43.0910
# Epoch 24/100
# 29/29 - 0s - 6ms/step - loss: 31.9911 - val_loss: 35.3856
# Epoch 25/100
# 29/29 - 0s - 7ms/step - loss: 28.4012 - val_loss: 33.9743
# Epoch 26/100
# 29/29 - 0s - 7ms/step - loss: 28.3961 - val_loss: 34.4636
# Epoch 27/100
# 29/29 - 0s - 6ms/step - loss: 27.6874 - val_loss: 35.2396
# Epoch 28/100
# 29/29 - 0s - 6ms/step - loss: 26.4935 - val_loss: 40.7420
# Epoch 29/100
# 29/29 - 0s - 6ms/step - loss: 25.0966 - val_loss: 32.2514
# Epoch 30/100
# 29/29 - 0s - 6ms/step - loss: 25.6353 - val_loss: 39.1945
# Epoch 31/100
# 29/29 - 0s - 6ms/step - loss: 27.0506 - val_loss: 33.7702
# Epoch 32/100
# 29/29 - 0s - 7ms/step - loss: 24.3455 - val_loss: 29.3906
# Epoch 33/100
# 29/29 - 0s - 7ms/step - loss: 23.5353 - val_loss: 29.6943
# Epoch 34/100
# 29/29 - 0s - 6ms/step - loss: 22.9766 - val_loss: 37.3316
# Epoch 35/100
# 29/29 - 0s - 6ms/step - loss: 21.6837 - val_loss: 34.9362
# Epoch 36/100
# 29/29 - 0s - 7ms/step - loss: 22.5694 - val_loss: 27.3113
# Epoch 37/100
# 29/29 - 0s - 7ms/step - loss: 21.8510 - val_loss: 32.6365
# Epoch 38/100
# 29/29 - 0s - 7ms/step - loss: 21.8252 - val_loss: 27.5322
# Epoch 39/100
# 29/29 - 0s - 7ms/step - loss: 19.9709 - val_loss: 29.3490
# Epoch 40/100
# 29/29 - 0s - 6ms/step - loss: 20.5796 - val_loss: 27.8276
# Epoch 41/100
# 29/29 - 0s - 6ms/step - loss: 20.2348 - val_loss: 26.5626
# Epoch 42/100
# 29/29 - 0s - 6ms/step - loss: 20.4648 - val_loss: 26.2428
# Epoch 43/100
# 29/29 - 0s - 6ms/step - loss: 19.6471 - val_loss: 24.8475
# Epoch 44/100
# 29/29 - 0s - 6ms/step - loss: 19.2413 - val_loss: 27.4522
# Epoch 45/100
# 29/29 - 0s - 6ms/step - loss: 18.5297 - val_loss: 25.6341
# Epoch 46/100
# 29/29 - 0s - 6ms/step - loss: 18.3724 - val_loss: 25.5178
# Epoch 47/100
# 29/29 - 0s - 8ms/step - loss: 18.5529 - val_loss: 26.4523
# Epoch 48/100
# 29/29 - 0s - 7ms/step - loss: 17.8546 - val_loss: 23.3409
# Epoch 49/100
# 29/29 - 0s - 6ms/step - loss: 19.2289 - val_loss: 29.4527
# Epoch 50/100
# 29/29 - 0s - 6ms/step - loss: 19.9328 - val_loss: 23.2044
# Epoch 51/100
# 29/29 - 0s - 6ms/step - loss: 17.2275 - val_loss: 30.5393
# Epoch 52/100
# 29/29 - 0s - 6ms/step - loss: 17.4108 - val_loss: 24.7781
# Epoch 53/100
# 29/29 - 0s - 6ms/step - loss: 17.6840 - val_loss: 26.9545
# Epoch 54/100
# 29/29 - 0s - 7ms/step - loss: 17.1669 - val_loss: 26.9405
# Epoch 55/100
# 29/29 - 0s - 6ms/step - loss: 16.7937 - val_loss: 24.1491
# Epoch 56/100
# 29/29 - 0s - 6ms/step - loss: 16.3944 - val_loss: 22.0010
# Epoch 57/100
# 29/29 - 0s - 6ms/step - loss: 15.7332 - val_loss: 24.9428
# Epoch 58/100
# 29/29 - 0s - 6ms/step - loss: 15.7583 - val_loss: 21.7577
# Epoch 59/100
# 29/29 - 0s - 6ms/step - loss: 15.7651 - val_loss: 22.2958
# Epoch 60/100
# 29/29 - 0s - 6ms/step - loss: 16.0448 - val_loss: 25.1996
# Epoch 61/100
# 29/29 - 0s - 6ms/step - loss: 16.7753 - val_loss: 20.7998
# Epoch 62/100
# 29/29 - 0s - 6ms/step - loss: 16.8597 - val_loss: 26.5186
# Epoch 63/100
# 29/29 - 0s - 6ms/step - loss: 15.3135 - val_loss: 21.1932
# Epoch 64/100
# 29/29 - 0s - 7ms/step - loss: 16.1086 - val_loss: 22.7655
# Epoch 65/100
# 29/29 - 0s - 6ms/step - loss: 15.0270 - val_loss: 25.4016
# Epoch 66/100
# 29/29 - 0s - 6ms/step - loss: 15.4008 - val_loss: 21.4212
# Epoch 67/100
# 29/29 - 0s - 6ms/step - loss: 14.3304 - val_loss: 22.9859
# Epoch 68/100
# 29/29 - 0s - 6ms/step - loss: 14.8820 - val_loss: 20.8861
# Epoch 69/100
# 29/29 - 0s - 6ms/step - loss: 14.3752 - val_loss: 20.6501
# Epoch 70/100
# 29/29 - 0s - 6ms/step - loss: 14.8788 - val_loss: 21.5347
# Epoch 71/100
# 29/29 - 0s - 6ms/step - loss: 13.9034 - val_loss: 20.7611
# Epoch 72/100
# 29/29 - 0s - 7ms/step - loss: 13.7207 - val_loss: 20.2921
# Epoch 73/100
# 29/29 - 0s - 6ms/step - loss: 14.4273 - val_loss: 21.9457
# Epoch 74/100
# 29/29 - 0s - 7ms/step - loss: 13.4924 - val_loss: 19.5890
# Epoch 75/100
# 29/29 - 0s - 6ms/step - loss: 13.7652 - val_loss: 20.5092
# Epoch 76/100
# 29/29 - 0s - 6ms/step - loss: 15.1676 - val_loss: 19.3242
# Epoch 77/100
# 29/29 - 0s - 6ms/step - loss: 13.9849 - val_loss: 19.8346
# Epoch 78/100
# 29/29 - 0s - 6ms/step - loss: 15.0579 - val_loss: 22.6590
# Epoch 79/100
# 29/29 - 0s - 7ms/step - loss: 13.9195 - val_loss: 19.7507
# Epoch 80/100
# 29/29 - 0s - 6ms/step - loss: 13.5456 - val_loss: 21.4132
# Epoch 81/100
# 29/29 - 0s - 7ms/step - loss: 13.3258 - val_loss: 23.1320
# Epoch 82/100
# 29/29 - 0s - 6ms/step - loss: 13.5791 - val_loss: 20.0796
# Epoch 83/100
# 29/29 - 0s - 6ms/step - loss: 13.2916 - val_loss: 18.1027
# Epoch 84/100
# 29/29 - 0s - 7ms/step - loss: 13.9760 - val_loss: 21.3039
# Epoch 85/100
# 29/29 - 0s - 6ms/step - loss: 13.0513 - val_loss: 18.9130
# Epoch 86/100
# 29/29 - 0s - 7ms/step - loss: 15.8051 - val_loss: 23.6323
# Epoch 87/100
# 29/29 - 0s - 7ms/step - loss: 13.0328 - val_loss: 19.9276
# Epoch 88/100
# 29/29 - 0s - 6ms/step - loss: 12.7724 - val_loss: 19.0678
# Epoch 89/100
# 29/29 - 0s - 7ms/step - loss: 13.0128 - val_loss: 19.5127
# Epoch 90/100
# 29/29 - 0s - 7ms/step - loss: 12.3523 - val_loss: 17.7471
# Epoch 91/100
# 29/29 - 0s - 6ms/step - loss: 12.1839 - val_loss: 18.7894
# Epoch 92/100
# 29/29 - 0s - 6ms/step - loss: 12.3858 - val_loss: 24.3816
# Epoch 93/100
# 29/29 - 0s - 6ms/step - loss: 12.1144 - val_loss: 18.9397
# Epoch 94/100
# 29/29 - 0s - 6ms/step - loss: 12.1121 - val_loss: 19.6279
# Epoch 95/100
# 29/29 - 0s - 6ms/step - loss: 12.9921 - val_loss: 19.9114
# Epoch 96/100
# 29/29 - 0s - 6ms/step - loss: 13.9325 - val_loss: 17.7802
# Epoch 97/100
# 29/29 - 0s - 7ms/step - loss: 12.3513 - val_loss: 22.8604
# Epoch 98/100
# 29/29 - 0s - 7ms/step - loss: 12.8844 - val_loss: 19.2997
# Epoch 99/100
# 29/29 - 0s - 6ms/step - loss: 12.1360 - val_loss: 17.4842
# Epoch 100/100
# 29/29 - 0s - 6ms/step - loss: 11.9253 - val_loss: 21.0159

# %% [markdown]
# Double-click <b>here</b> for the solution.
#
# <!-- Your answer is below:
# # build the model
# model = regression_model()
# model.fit(predictors_norm, target, validation_split=0.1, epochs=100, verbose=2)
#
# -->

# %% [markdown]
# Based on the results, we notice that:
#
# - Adding more hidden layers to the model increases its capacity to learn and represent complex relationships within the data. This allows the model to better identify, as a result, the model becomes more effective at fitting the training data and potentially improving its predictions.
# - By reducing the proportion of data set aside for validation and using a larger portion for training, the model has access to more examples to learn from. This additional training data helps the model improve its understanding of the underlying trends, which can lead to better overall performance.

# %% [markdown]
# ### Thank you for completing this lab!
#
# This notebook was created by [Alex Aklson](https://www.linkedin.com/in/aklson/). I hope you found this lab interesting and educational. Feel free to contact me if you have any questions!

# %% [markdown]
# <!--
# ## Change Log
#
# |  Date (YYYY-MM-DD) |  Version | Changed By  |  Change Description |
# |---|---|---|---|
# | 2024-11-20  | 3.0  | Aman  |  Updated the library versions to current |
# | 2020-09-21  | 2.0  | Srishti  |  Migrated Lab to Markdown and added to course repo in GitLab |
#
#
#
# <hr>
#
# ## <h3 align="center"> © IBM Corporation. All rights reserved. <h3/>

# %% [markdown]
# ## <h3 align="center"> &#169; IBM Corporation. All rights reserved. <h3/>
