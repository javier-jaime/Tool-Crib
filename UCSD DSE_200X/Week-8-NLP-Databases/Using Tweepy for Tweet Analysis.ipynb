# %% [markdown]
# # Twitter data
#
# ## Copyright and Licensing
#
# You are free to use or adapt this notebook for any purpose you'd like. However, please respect the [Simplified BSD License](https://github.com/ptwobrussell/Mining-the-Social-Web-2nd-Edition/blob/master/LICENSE.txt) that governs its use.

# %% [markdown]
# ### Please Note:
#
# This notebook likely looks a little different from the video content in the course. This notebook has been modified to be easier to understand as Tweepy is generally an easier package to work with. The old notebooks will still be available in the course downloads page if desired, but they will not be regularly updated.

# %% [markdown]
# # Twitter API Access
#
# In order to use it to make requests to Twitter's API, you'll need to go to https://dev.twitter.com/apps and create a sample application.
#
# Choose any name for your application, write a description and use `http://google.com` for the website. Further instructions can be found in week 6 of the course.
#
# Under **Key and Access Tokens**, there are four primary identifiers you'll need to note:
# * consumer key,
# * consumer secret,
# * access token, and
# * access token secret (Click on Create Access Token to create those).
#
# Note that you will need an ordinary Twitter account in order to login, create an app, and get these credentials.

# %% [markdown]
# Install the `tweepy` package to interface with the Twitter API

# %%
#pip install for the package we will be using
# !pip install tweepy
# Out:
# Collecting tweepy
#   Using cached tweepy-3.9.0-py2.py3-none-any.whl (30 kB)
# Collecting requests-oauthlib>=0.7.0
#   Using cached requests_oauthlib-1.3.0-py2.py3-none-any.whl (23 kB)
# Requirement already satisfied: six>=1.10.0 in d:\anaconda3\lib\site-packages (from tweepy) (1.15.0)
# Requirement already satisfied: requests[socks]>=2.11.1 in d:\anaconda3\lib\site-packages (from tweepy) (2.24.0)
# Collecting oauthlib>=3.0.0
#   Using cached oauthlib-3.1.0-py2.py3-none-any.whl (147 kB)
# Requirement already satisfied: chardet<4,>=3.0.2 in d:\anaconda3\lib\site-packages (from requests[socks]>=2.11.1->tweepy) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in d:\anaconda3\lib\site-packages (from requests[socks]>=2.11.1->tweepy) (1.25.11)
# Requirement already satisfied: certifi>=2017.4.17 in d:\anaconda3\lib\site-packages (from requests[socks]>=2.11.1->tweepy) (2020.6.20)
# Requirement already satisfied: idna<3,>=2.5 in d:\anaconda3\lib\site-packages (from requests[socks]>=2.11.1->tweepy) (2.10)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6; extra == "socks" in d:\anaconda3\lib\site-packages (from requests[socks]>=2.11.1->tweepy) (1.7.1)
# Installing collected packages: oauthlib, requests-oauthlib, tweepy
# Successfully installed oauthlib-3.1.0 requests-oauthlib-1.3.0 tweepy-3.9.0

# %% [markdown]
# ## Example 1. Authorizing an application to access Twitter account data

# %%
import tweepy

#Setting up the keys and tokens
c_k = "TfibBlsCrxw9IOrHrgrQs3Bx1"
c_s = "8H5eWZM3ZLSgABFhwNrFNxakOsYPY2Kl9aDTzC9LMeToJdu1As"

a_t = "1319004281148592128-weJBkm4DsyRXXpcMlUOVAg3aRRN4oO"
a_s = "RF4y3DV08XbHoRhS0cpESdokfjja6QFTuHa2ShG6EpZJ8"

auth = tweepy.OAuthHandler(c_k, c_s)
auth.set_access_token(a_t, a_s)
api = tweepy.API(auth)

# Nothing to see by displaying twitter_api except that it's now a
# defined variable

print(api)
# Out:
# <tweepy.api.API object at 0x000001C0F74DEF40>

# %% [markdown]
# ## Example 2. Retrieving trends

# %% [markdown]
# Twitter identifies locations using the Yahoo! Where On Earth ID.
#
# The Yahoo! Where On Earth ID for the entire world is 1.
# See https://dev.twitter.com/docs/api/1.1/get/trends/place and
# http://developer.yahoo.com/geo/geoplanet/
#
# look at the BOSS placefinder here: https://developer.yahoo.com/boss/placefinder/
#
# To look up an area use:
# https://www.findmecity.com/

# %%
WORLD_WOE_ID = 1
US_WOE_ID = 23424977

# %% [markdown]
# Look up the WOE ID for "San Diego" and you should find the following ID below defined as "LOCAL_WOE_ID".
#
# You can change this if you would like.

# %%
LOCAL_WOE_ID=8775 # Calgary

# Prefix ID with the underscore for query string parameterization.
# Without the underscore, the twitter package appends the ID value
# to the URL itself as a special case keyword argument.

world_trends = api.trends_place(WORLD_WOE_ID)
us_trends = api.trends_place(US_WOE_ID)
local_trends = api.trends_place(LOCAL_WOE_ID)

# %%
world_trends[:2]
# Out:
# [{'trends': [{'name': '#FreeCodeFridayContest',
#     'url': 'http://twitter.com/search?q=%23FreeCodeFridayContest',
#     'promoted_content': None,
#     'query': '%23FreeCodeFridayContest',
#     'tweet_volume': None},
#    {'name': 'Oscar Isaac',
#     'url': 'http://twitter.com/search?q=%22Oscar+Isaac%22',
#     'promoted_content': None,
#     'query': '%22Oscar+Isaac%22',
#     'tweet_volume': 20609},
#    {'name': '#OurHomeSoobinDay',
#     'url': 'http://twitter.com/search?q=%23OurHomeSoobinDay',
#     'promoted_content': None,
#     'query': '%23OurHomeSoobinDay',
#     'tweet_volume': 496282},
#    {'name': '#luppo',
#     'url': 'http://twitter.com/search?q=%23luppo',
#     'promoted_content': None,
#     'query': '%23luppo',
#     'tweet_volume': None},
#    {'name': '#BJKvKAS',
#     'url': 'http://twitter.com/search?q=%23BJKvKAS',
#     'promoted_content': None,
#     'query': '%23BJKvKAS',
#     'tweet_volume': 17343},
#    {'name': '#STFOrganizacaoCriminosa',
#     'url': 'http://twitter.com/search?q=%23STFOrganizacaoCriminosa',
#     'promoted_content': None,
#     'query': '%23STFOrganizacaoCriminosa',
#     'tweet_volume': 51295},
#    {'name': 'Solid Snake',
#     'url': 'http://twitter.com/search?q=%22Solid+Snake%22',
#     'promoted_content': None,
#     'query': '%22Solid+Snake%22',
#     'tweet_volume': 20826},
#    {'name': 'Momon',
#     'url': 'http://twitter.com/search?q=Momon',
#     'promoted_content': None,
#     'query': 'Momon',
#     'tweet_volume': 20519},
#    {'name': 'Bottas',
#     'url': 'http://twitter.com/search?q=Bottas',
#     'promoted_content': None,
#     'query': 'Bottas',
#     'tweet_volume': 18322},
#    {'name': 'Selena',
#     'url': 'http://twitter.com/search?q=Selena',
#     'promoted_content': None,
#     'query': 'Selena',
#     'tweet_volume': 106520},
#    {'name': 'Metal Gear Solid',
#     'url': 'http://twitter.com/search?q=%22Metal+Gear+Solid%22',
#     'promoted_content': None,
#     'query': '%22Metal+Gear+Solid%22',
#     'tweet_volume': 16910},
#    {'name': 'Pelosi',
#     'url': 'http://twitter.com/search?q=Pelosi',
#     'promoted_content': None,
#     'query': 'Pelosi',
#     'tweet_volume': 90977},
#    {'name': 'Marcius Melhem',
#     'url': 'http://twitter.com/search?q=%22Marcius+Melhem%22',
#     'promoted_content': None,
#     'query': '%22Marcius+Melhem%22',
#     'tweet_volume': 33080},
#    {'name': 'Rick Santelli',
#     'url': 'http://twitter.com/search?q=%22Rick+Santelli%22',
#     'promoted_content': None,
#     'query': '%22Rick+Santelli%22',
#     'tweet_volume': 11173},
#    {'name': 'じゅじゅさんぽ',
#     'url': 'http://twitter.com/search?q=%E3%81%98%E3%82%85%E3%81%98%E3%82%85%E3%81%95%E3%82%93%E3%81%BD',
#     'promoted_content': None,
#     'query': '%E3%81%98%E3%82%85%E3%81%98%E3%82%85%E3%81%95%E3%82%93%E3%81%BD',
#     'tweet_volume': None},
#    {'name': 'Fred Hampton',
#     'url': 'http://twitter.com/search?q=%22Fred+Hampton%22',
#     'promoted_content': None,
#     'query': '%22Fred+Hampton%22',
#     'tweet_volume': 39984},
#    {'name': 'ReformunAdı TersKelepçe',
#     'url': 'http://twitter.com/search?q=%22ReformunAd%C4%B1+TersKelep%C3%A7e%22',
#     'promoted_content': None,
#     'query': '%22ReformunAd%C4%B1+TersKelep%C3%A7e%22',
#     'tweet_volume': 25125},
#    {'name': 'Dani Calabresa',
#     'url': 'http://twitter.com/search?q=%22Dani+Calabresa%22',
#     'promoted_content': None,
#     'query': '%22Dani+Calabresa%22',
#     'tweet_volume': 23054},
#    {'name': 'Big Mouth',
#     'url': 'http://twitter.com/search?q=%22Big+Mouth%22',
#     'promoted_content': None,
#     'query': '%22Big+Mouth%22',
#     'tweet_volume': 19509},
#    {'name': 'Big Boss',
#     'url': 'http://twitter.com/search?q=%22Big+Boss%22',
#     'promoted_content': None,
#     'query': '%22Big+Boss%22',
#     'tweet_volume': None},
#    {'name': 'GelecekSende BilgiOcakta',
#     'url': 'http://twitter.com/search?q=%22GelecekSende+BilgiOcakta%22',
#     'promoted_content': None,
#     'query': '%22GelecekSende+BilgiOcakta%22',
#     'tweet_volume': 18112},
#    {'name': 'Russell',
#     'url': 'http://twitter.com/search?q=Russell',
#     'promoted_content': None,
#     'query': 'Russell',
#     'tweet_volume': 64009},
#    {'name': 'Centro de Gobierno',
#     'url': 'http://twitter.com/search?q=%22Centro+de+Gobierno%22',
#     'promoted_content': None,
#     'query': '%22Centro+de+Gobierno%22',
#     'tweet_volume': None},
#    {'name': 'FUBU',
#     'url': 'http://twitter.com/search?q=FUBU',
#     'promoted_content': None,
#     'query': 'FUBU',
#     'tweet_volume': None},
#    {'name': 'Mika',
#     'url': 'http://twitter.com/search?q=Mika',
#     'promoted_content': None,
#     'query': 'Mika',
#     'tweet_volume': 40461},
#    {'name': 'The Royals',
#     'url': 'http://twitter.com/search?q=%22The+Royals%22',
#     'promoted_content': None,
#     'query': '%22The+Royals%22',
#     'tweet_volume': None},
#    {'name': 'Matt Gaetz',
#     'url': 'http://twitter.com/search?q=%22Matt+Gaetz%22',
#     'promoted_content': None,
#     'query': '%22Matt+Gaetz%22',
#     'tweet_volume': 12140},
#    {'name': 'Joe Anderson',
#     'url': 'http://twitter.com/search?q=%22Joe+Anderson%22',
#     'promoted_content': None,
#     'query': '%22Joe+Anderson%22',
#     'tweet_volume': None},
#    {'name': 'Constituição',
#     'url': 'http://twitter.com/search?q=Constitui%C3%A7%C3%A3o',
#     'promoted_content': None,
#     'query': 'Constitui%C3%A7%C3%A3o',
#     'tweet_volume': 110328},
#    {'name': 'Ghezzal',
#     'url': 'http://twitter.com/search?q=Ghezzal',
#     'promoted_content': None,
#     'query': 'Ghezzal',
#     'tweet_volume': None},
#    {'name': 'Kojima',
#     'url': 'http://twitter.com/search?q=Kojima',
#     'promoted_content': None,
#     'query': 'Kojima',
#     'tweet_volume': None},
#    {'name': 'Shakira',
#     'url': 'http://twitter.com/search?q=Shakira',
#     'promoted_content': None,
#     'query': 'Shakira',
#     'tweet_volume': 38296},
#    {'name': 'Boba Fett',
#     'url': 'http://twitter.com/search?q=%22Boba+Fett%22',
#     'promoted_content': None,
#     'query': '%22Boba+Fett%22',
#     'tweet_volume': 11798},
#    {'name': 'KalptekiAşk KeremBürsin',
#     'url': 'http://twitter.com/search?q=%22KalptekiA%C5%9Fk+KeremB%C3%BCrsin%22',
#     'promoted_content': None,
#     'query': '%22KalptekiA%C5%9Fk+KeremB%C3%BCrsin%22',
#     'tweet_volume': 33958},
#    {'name': 'Mank',
#     'url': 'http://twitter.com/search?q=Mank',
#     'promoted_content': None,
#     'query': 'Mank',
#     'tweet_volume': 18652},
#    {'name': 'PicPay',
#     'url': 'http://twitter.com/search?q=PicPay',
#     'promoted_content': None,
#     'query': 'PicPay',
#     'tweet_volume': 27170},
#    {'name': 'Mulan',
#     'url': 'http://twitter.com/search?q=Mulan',
#     'promoted_content': None,
#     'query': 'Mulan',
#     'tweet_volume': 24549},
#    {'name': 'ういちゃん',
#     'url': 'http://twitter.com/search?q=%E3%81%86%E3%81%84%E3%81%A1%E3%82%83%E3%82%93',
#     'promoted_content': None,
#     'query': '%E3%81%86%E3%81%84%E3%81%A1%E3%82%83%E3%82%93',
#     'tweet_volume': None},
#    {'name': 'Marijuana',
#     'url': 'http://twitter.com/search?q=Marijuana',
#     'promoted_content': None,
#     'query': 'Marijuana',
#     'tweet_volume': 105050},
#    {'name': 'Anouk',
#     'url': 'http://twitter.com/search?q=Anouk',
#     'promoted_content': None,
#     'query': 'Anouk',
#     'tweet_volume': None},
#    {'name': 'João Monlevade',
#     'url': 'http://twitter.com/search?q=%22Jo%C3%A3o+Monlevade%22',
#     'promoted_content': None,
#     'query': '%22Jo%C3%A3o+Monlevade%22',
#     'tweet_volume': None},
#    {'name': 'リュウソウジャー',
#     'url': 'http://twitter.com/search?q=%E3%83%AA%E3%83%A5%E3%82%A6%E3%82%BD%E3%82%A6%E3%82%B8%E3%83%A3%E3%83%BC',
#     'promoted_content': None,
#     'query': '%E3%83%AA%E3%83%A5%E3%82%A6%E3%82%BD%E3%82%A6%E3%82%B8%E3%83%A3%E3%83%BC',
#     'tweet_volume': None},
#    {'name': 'The House',
#     'url': 'http://twitter.com/search?q=%22The+House%22',
#     'promoted_content': None,
#     'query': '%22The+House%22',
#     'tweet_volume': 440961},
#    {'name': 'COMO ME CONQUISTAR PELA BOCA',
#     'url': 'http://twitter.com/search?q=%22COMO+ME+CONQUISTAR+PELA+BOCA%22',
#     'promoted_content': None,
#     'query': '%22COMO+ME+CONQUISTAR+PELA+BOCA%22',
#     'tweet_volume': None},
#    {'name': 'Akaashi',
#     'url': 'http://twitter.com/search?q=Akaashi',
#     'promoted_content': None,
#     'query': 'Akaashi',
#     'tweet_volume': 27342},
#    {'name': 'Happy Founders',
#     'url': 'http://twitter.com/search?q=%22Happy+Founders%22',
#     'promoted_content': None,
#     'query': '%22Happy+Founders%22',
#     'tweet_volume': 13098},
#    {'name': 'Bonner',
#     'url': 'http://twitter.com/search?q=Bonner',
#     'promoted_content': None,
#     'query': 'Bonner',
#     'tweet_volume': None},
#    {'name': 'Euphoria',
#     'url': 'http://twitter.com/search?q=Euphoria',
#     'promoted_content': None,
#     'query': 'Euphoria',
#     'tweet_volume': 167333},
#    {'name': 'Atiba',
#     'url': 'http://twitter.com/search?q=Atiba',
#     'promoted_content': None,
#     'query': 'Atiba',
#     'tweet_volume': None},
#    {'name': 'CNBC',
#     'url': 'http://twitter.com/search?q=CNBC',
#     'promoted_content': None,
#     'query': 'CNBC',
#     'tweet_volume': 45836}],
#   'as_of': '2020-12-04T20:13:45Z',
#   'created_at': '2020-12-03T15:21:36Z',
#   'locations': [{'name': 'Worldwide', 'woeid': 1}]}]

# %%
trends=local_trends
print(type(trends))
print(list(trends[0].keys()))
print(trends[0]['trends'])
# Out:
# <class 'list'>
# ['trends', 'as_of', 'created_at', 'locations']
# [{'name': '#FreeCodeFridayContest', 'url': 'http://twitter.com/search?q=%23FreeCodeFridayContest', 'promoted_content': None, 'query': '%23FreeCodeFridayContest', 'tweet_volume': None}, {'name': 'Terry Fox', 'url': 'http://twitter.com/search?q=%22Terry+Fox%22', 'promoted_content': None, 'query': '%22Terry+Fox%22', 'tweet_volume': None}, {'name': 'Bytowne', 'url': 'http://twitter.com/search?q=Bytowne', 'promoted_content': None, 'query': 'Bytowne', 'tweet_volume': None}, {'name': 'Oscar Isaac', 'url': 'http://twitter.com/search?q=%22Oscar+Isaac%22', 'promoted_content': None, 'query': '%22Oscar+Isaac%22', 'tweet_volume': 20609}, {'name': 'CERB', 'url': 'http://twitter.com/search?q=CERB', 'promoted_content': None, 'query': 'CERB', 'tweet_volume': None}, {'name': 'Solid Snake', 'url': 'http://twitter.com/search?q=%22Solid+Snake%22', 'promoted_content': None, 'query': '%22Solid+Snake%22', 'tweet_volume': 20876}, {'name': '#FridayFeeling', 'url': 'http://twitter.com/search?q=%23FridayFeeling', 'promoted_content': None, 'query': '%23FridayFeeling', 'tweet_volume': 30182}, {'name': '#NoEncampmentEvictions', 'url': 'http://twitter.com/search?q=%23NoEncampmentEvictions', 'promoted_content': None, 'query': '%23NoEncampmentEvictions', 'tweet_volume': None}, {'name': '#DragonAgeDay', 'url': 'http://twitter.com/search?q=%23DragonAgeDay', 'promoted_content': None, 'query': '%23DragonAgeDay', 'tweet_volume': None}, {'name': '#NationalCookieDay', 'url': 'http://twitter.com/search?q=%23NationalCookieDay', 'promoted_content': None, 'query': '%23NationalCookieDay', 'tweet_volume': None}, {'name': 'Metal Gear', 'url': 'http://twitter.com/search?q=%22Metal+Gear%22', 'promoted_content': None, 'query': '%22Metal+Gear%22', 'tweet_volume': 23129}, {'name': 'DONALD TRUMP WON', 'url': 'http://twitter.com/search?q=%22DONALD+TRUMP+WON%22', 'promoted_content': None, 'query': '%22DONALD+TRUMP+WON%22', 'tweet_volume': 30293}, {'name': 'Big Boss', 'url': 'http://twitter.com/search?q=%22Big+Boss%22', 'promoted_content': None, 'query': '%22Big+Boss%22', 'tweet_volume': None}, {'name': 'soobin', 'url': 'http://twitter.com/search?q=soobin', 'promoted_content': None, 'query': 'soobin', 'tweet_volume': 606608}, {'name': 'Bottas', 'url': 'http://twitter.com/search?q=Bottas', 'promoted_content': None, 'query': 'Bottas', 'tweet_volume': 18322}, {'name': 'SANTELLI', 'url': 'http://twitter.com/search?q=SANTELLI', 'promoted_content': None, 'query': 'SANTELLI', 'tweet_volume': 14215}, {'name': 'Kojima', 'url': 'http://twitter.com/search?q=Kojima', 'promoted_content': None, 'query': 'Kojima', 'tweet_volume': None}, {'name': 'Jay-Z', 'url': 'http://twitter.com/search?q=Jay-Z', 'promoted_content': None, 'query': 'Jay-Z', 'tweet_volume': 24877}, {'name': 'FNCS', 'url': 'http://twitter.com/search?q=FNCS', 'promoted_content': None, 'query': 'FNCS', 'tweet_volume': 12465}, {'name': 'Ottawa', 'url': 'http://twitter.com/search?q=Ottawa', 'promoted_content': None, 'query': 'Ottawa', 'tweet_volume': None}, {'name': 'Park West', 'url': 'http://twitter.com/search?q=%22Park+West%22', 'promoted_content': None, 'query': '%22Park+West%22', 'tweet_volume': None}, {'name': 'Bas-Saint-Laurent', 'url': 'http://twitter.com/search?q=Bas-Saint-Laurent', 'promoted_content': None, 'query': 'Bas-Saint-Laurent', 'tweet_volume': None}, {'name': 'Queen of England', 'url': 'http://twitter.com/search?q=%22Queen+of+England%22', 'promoted_content': None, 'query': '%22Queen+of+England%22', 'tweet_volume': None}, {'name': 'oikawa', 'url': 'http://twitter.com/search?q=oikawa', 'promoted_content': None, 'query': 'oikawa', 'tweet_volume': 42731}, {'name': 'Majah', 'url': 'http://twitter.com/search?q=Majah', 'promoted_content': None, 'query': 'Majah', 'tweet_volume': None}, {'name': 'Mass Effect 2', 'url': 'http://twitter.com/search?q=%22Mass+Effect+2%22', 'promoted_content': None, 'query': '%22Mass+Effect+2%22', 'tweet_volume': None}, {'name': 'Mank', 'url': 'http://twitter.com/search?q=Mank', 'promoted_content': ...

# %% [markdown]
# ## Example 3. Displaying API responses as pretty-printed JSON

# %%
import json

print((json.dumps(us_trends[:2], indent=1)))
# Out:
# [
#  {
#   "trends": [
#    {
#     "name": "#FreeCodeFridayContest",
#     "url": "http://twitter.com/search?q=%23FreeCodeFridayContest",
#     "promoted_content": null,
#     "query": "%23FreeCodeFridayContest",
#     "tweet_volume": null
#    },
#    {
#     "name": "Oscar Isaac",
#     "url": "http://twitter.com/search?q=%22Oscar+Isaac%22",
#     "promoted_content": null,
#     "query": "%22Oscar+Isaac%22",
#     "tweet_volume": 20609
#    },
#    {
#     "name": "#pmgiveaway",
#     "url": "http://twitter.com/search?q=%23pmgiveaway",
#     "promoted_content": null,
#     "query": "%23pmgiveaway",
#     "tweet_volume": 29742
#    },
#    {
#     "name": "#NationalCookieDay",
#     "url": "http://twitter.com/search?q=%23NationalCookieDay",
#     "promoted_content": null,
#     "query": "%23NationalCookieDay",
#     "tweet_volume": null
#    },
#    {
#     "name": "Selena",
#     "url": "http://twitter.com/search?q=Selena",
#     "promoted_content": null,
#     "query": "Selena",
#     "tweet_volume": 106578
#    },
#    {
#     "name": "Pelosi",
#     "url": "http://twitter.com/search?q=Pelosi",
#     "promoted_content": null,
#     "query": "Pelosi",
#     "tweet_volume": 90977
#    },
#    {
#     "name": "Rick Santelli",
#     "url": "http://twitter.com/search?q=%22Rick+Santelli%22",
#     "promoted_content": null,
#     "query": "%22Rick+Santelli%22",
#     "tweet_volume": 11191
#    },
#    {
#     "name": "Fred Hampton",
#     "url": "http://twitter.com/search?q=%22Fred+Hampton%22",
#     "promoted_content": null,
#     "query": "%22Fred+Hampton%22",
#     "tweet_volume": 39984
#    },
#    {
#     "name": "#TheMandalorian",
#     "url": "http://twitter.com/search?q=%23TheMandalorian",
#     "promoted_content": null,
#     "query": "%23TheMandalorian",
#     "tweet_volume": 54356
#    },
#    {
#     "name": "Royals",
#     "url": "http://twitter.com/search?q=Royals",
#     "promoted_content": null,
#     "query": "Royals",
#     "tweet_volume": 10626
#    },
#    {
#     "name": "FUBU",
#     "url": "http://twitter.com/search?q=FUBU",
#     "promoted_content": null,
#     "query": "FUBU",
#     "tweet_volume": null
#    },
#    {
#     "name": "#MattPutz",
#     "url": "http://twitter.com/search?q=%23MattPutz",
#     "promoted_content": null,
#     "query": "%23MattPutz",
#     "tweet_volume": null
#    },
#    {
#     "name": "Matt Gaetz",
#     "url": "http://twitter.com/search?q=%22Matt+Gaetz%22",
#     "promoted_content": null,
#     "query": "%22Matt+Gaetz%22",
#     "tweet_volume": 12220
#    },
#    {
#     "name": "soobin",
#     "url": "http://twitter.com/search?q=soobin",
#     "promoted_content": null,
#     "query": "soobin",
#     "tweet_volume": 606395
#    },
#    {
#     "name": "Metal Gear Solid",
#     "url": "http://twitter.com/search?q=%22Metal+Gear+Solid%22",
#     "promoted_content": null,
#     "query": "%22Metal+Gear+Solid%22",
#     "tweet_volume": 16910
#    },
#    {
#     "name": "Marijuana",
#     "url": "http://twitter.com/search?q=Marijuana",
#     "promoted_content": null,
#     "query": "Marijuana",
#     "tweet_volume": 105050
#    },
#    {
#     "name": "The House",
#     "url": "http://twitter.com/search?q=%22The+House%22",
#     "promoted_content": null,
#     "query": "%22The+House%22",
#     "tweet_volume": 440961
#    },
#    {
#     "name": "Big Boss",
#     "url": "http://twitter.com/search?q=%22Big+Boss%22",
#     "promoted_content": null,
#     "query": "%22Big+Boss%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "Big Mouth",
#     "url": "http://twitter.com/search?q=%22Big+Mouth%22",
#     "promoted_content": null,
#     "query": "%22Big+Mouth%22",
#     "tweet_volume": 19509
#    },
#    {
#     "name": "Happy Founders",
#     "url": "http://twitter.com/search?q=%22Happy+Founders%22",
#     "promoted_content": null,
#     "query": "%22Happy+Founders%22",
#     "tweet_volume": 13105
#    },
#    {
#     "name": "CNBC",
#     "url": "http://twitter.com/search?q=CNBC",
#     "promoted_content": null,
#     "query": "CNBC",
#     "tweet_volume": 45739
#    },
#    {
#     "name": "Over 50",
#     "url": "http://twitter.com/search?q=%22Over+50%22",
#     "promoted_content": null,
#     "query": "%22Over+50%22",
#     "tweet_volume": 32555
#    },
#    {
#     "name": "Kojima",
#     "url": "http://twitter.com/search?q=Kojima",
#     "promoted_content": null,
#     "query": "Kojima",
#     "tweet_volume": null
#    },
#    {
#     "name": "Jay-Z",
#     "url": "http://twitter.com/search?q=Jay-Z",
#     "promoted_content": null,
#     "query": "Jay-Z",
#     "tweet_volume": 24778
#    },
#    {
#     "name": "Founders Day",
#     "url": "http://twitter.com/search?q=%22Founders+Day%22",
#     "promoted_content": null,
#     "query": "%22Founders+Day%22",
#     "tweet_volume": 15109
#    },
#    {
#     "name": "Luguentz Dort",
#     "url": "http://twitter.com/search?q=%22Luguentz+Dort%22",
#     "promoted_content": null,
#     "query": "%22Luguentz+Dort%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "Queen of England",
#     "url": "http://twitter.com/search?q=%22Queen+of+England%22",
#     "promoted_content": null,
#     "query": "%22Queen+of+England%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "Mank",
#     "url": "http://twitter.com/search?q=Mank",
#     "promoted_content": null,
#     "query": "Mank",
#     "tweet_volume": 18652
#    },
#    {
#     "name": "Boba Fett",
#     "url": "http://twitter.com/search?q=%22Boba+Fett%22",
#     "promoted_content": null,
#     "query": "%22Boba+Fett%22",
#     "tweet_volume": 11798
#    },
#    {
#     "name": "Michelle Bachman",
#     "url": "http://twitter.com/search?q=%22Michelle+Bachman%22",
#     "promoted_content": null,
#     "query": "%22Michelle+Bachman%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "Slave 4 U",
#     "url": "http://twitter.com/search?q=%22Slave+4+U%22",
#     "promoted_content": null,
#     "query": "%22Slave+4+U%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "Kraelo",
#     "url": "http://twitter.com/search?q=Kraelo",
#     "promoted_content": null,
#     "query": "Kraelo",
#     "tweet_volume": null
#    },
#    {
#     "name": "Akaashi",
#     "url": "http://twitter.com/search?q=Akaashi",
#     "promoted_content": null,
#     "query": "Akaashi",
#     "tweet_volume": 27342
#    },
#    {
#     "name": "Beer",
#     "url": "http://twitter.com/search?q=Beer",
#     "promoted_content": null,
#     "query": "Beer",
#     "tweet_volume": 100819
#    },
#    {
#     "name": "Prada bag",
#     "url": "http://twitter.com/search?q=%22Prada+bag%22",
#     "promoted_content": null,
#     "query": "%22Prada+bag%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "Lil Baby",
#     "url": "http://twitter.com/search?q=%22Lil+Baby%22",
#     "promoted_content": null,
#     "query": "%22Lil+Baby%22",
#     "tweet_volume": 56180
#    },
#    {
#     "name": "Psycho Mantis",
#     "url": "http://twitter.com/search?q=%22Psycho+Mantis%22",
#     "promoted_content": null,
#     "query": "%22Psycho+Mantis%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "Soda",
#     "url": "http://twitter.com/search?q=Soda",
#     "promoted_content": null,
#     "query": "Soda",
#     "tweet_volume": 41066
#    },
#    {
#     "name": "Cullen",
#     "url": "http://twitter.com/search?q=Cullen",
#     "promoted_content": null,
#     "query": "Cullen",
#     "tweet_volume": 10788
#    },
#    {
#     "name": "Mass Effect 2",
#     "url": "http://twitter.com/search?q=%22Mass+Effect+2%22",
#     "promoted_content": null,
#     "query": "%22Mass+Effect+2%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "5 Republicans",
#     "url": "http://twitter.com/search?q=%225+Republicans%22",
#     "promoted_content": null,
#     "query": "%225+Republicans%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "Tea Party",
#     "url": "http://twitter.com/search?q=%22Tea+Party%22",
#     "promoted_content": null,
#     "query": "%22Tea+Party%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "Jayda",
#     "url": "http://twitter.com/search?q=Jayda",
#     "promoted_content": null,
#     "query": "Jayda",
#     "tweet_volume": 11224
#    },
#    {
#     "name": "Defense Business Board",
#     "url": "http://twitter.com/search?q=%22Defense+Business+Board%22",
#     "promoted_content": null,
#     "query": "%22Defense+Business+Board%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "DeJoy",
#     "url": "http://twitter.com/search?q=DeJoy",
#     "promoted_content": null,
#     "query": "DeJoy",
#     "tweet_volume": 13922
#    },
#    {
#     "name": "Cerberus",
#     "url": "http://twitter.com/search?q=Cerberus",
#     "promoted_content": null,
#     "query": "Cerberus",
#     "tweet_volume": null
#    },
#    {
#     "name": "Reasonable Doubt",
#     "url": "http://twitter.com/search?q=%22Reasonable+Doubt%22",
#     "promoted_content": null,
#     "query": "%22Reasonable+Doubt%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "Sorkin",
#     "url": "http://twitter.com/search?q=Sorkin",
#     "promoted_content": null,
#     "query": "Sorkin",
#     "tweet_volume": null
#    },
#    {
#     "name": "Medusa",
#     "url": "http://twitter.com/search?q=Medusa",
#     "promoted_content": null,
#     "query": "Medusa",
#     "tweet_volume": null
#    },
#    {
#     "name": "6 Dems",
#     "url": "http://twitter.com/search?q=%226+Dems%22",
#     "promoted_content": null,
#     "query": "%226+Dems%22",
#     "tweet_volume": null
#    }
#   ],
#   "as_of": "2020-12-04T20:13:45Z",
#   "created_at": "2020-12-03T15:21:36Z",
#   "locations": [
#    {
#     "name": "United States",
#     "woeid": 23424977
#    }
#   ]
#  }
# ]

# %% [markdown]
# ## Example 4. Computing the intersection of two sets of trends

# %%
trends_set = {}
trends_set['world'] = set([trend['name'] 
                        for trend in world_trends[0]['trends']])

trends_set['us'] = set([trend['name'] 
                     for trend in us_trends[0]['trends']]) 

trends_set['Calgary'] = set([trend['name'] 
                     for trend in local_trends[0]['trends']])

# %%
for loc in ['world','us','Calgary']:
    print(('-'*10,loc))
    print((','.join(trends_set[loc])))
# Out:
# ('----------', 'world')
# ReformunAdı TersKelepçe,Mika,Metal Gear Solid,Russell,KalptekiAşk KeremBürsin,Boba Fett,Pelosi,Mulan,Matt Gaetz,リュウソウジャー,COMO ME CONQUISTAR PELA BOCA,#STFOrganizacaoCriminosa,Marijuana,Joe Anderson,The House,Bottas,Kojima,The Royals,Marcius Melhem,Dani Calabresa,Atiba,#OurHomeSoobinDay,CNBC,Centro de Gobierno,Selena,Fred Hampton,#FreeCodeFridayContest,Momon,#BJKvKAS,Akaashi,Bonner,ういちゃん,Mank,Anouk,Oscar Isaac,PicPay,#luppo,じゅじゅさんぽ,Euphoria,Big Mouth,João Monlevade,FUBU,Ghezzal,Happy Founders,GelecekSende BilgiOcakta,Rick Santelli,Constituição,Solid Snake,Big Boss,Shakira
# ('----------', 'us')
# Royals,Soda,#NationalCookieDay,Defense Business Board,Metal Gear Solid,Boba Fett,Pelosi,Queen of England,Matt Gaetz,Marijuana,Psycho Mantis,Cerberus,soobin,Beer,#pmgiveaway,The House,Michelle Bachman,Kojima,#TheMandalorian,Slave 4 U,DeJoy,Prada bag,CNBC,Mass Effect 2,5 Republicans,Selena,Fred Hampton,#FreeCodeFridayContest,Jay-Z,Akaashi,Reasonable Doubt,Tea Party,Mank,Oscar Isaac,Medusa,6 Dems,Luguentz Dort,Big Mouth,Sorkin,Cullen,FUBU,Over 50,Happy Founders,Jayda,Rick Santelli,Kraelo,Big Boss,Lil Baby,Founders Day,#MattPutz
# ('----------', 'Calgary')
# Amir,Bytowne,#NationalCookieDay,Bas-Saint-Laurent,Boba Fett,Pelosi,mind-blowing liberal,Queen of England,Greenbelt,Finch,DONALD TRUMP WON,Ottawa,Gitanjali Rao,soobin,Beer,Miley Cyrus,Theo,Bottas,SANTELLI,Sound of Metal,Metal Gear,Park West,Kojima,National Day of Remembrance,CERB,oikawa,larry mavety,Mass Effect 2,Gaetz,Fred Hampton,Terry Fox,#FreeCodeFridayContest,Jay-Z,Akaashi,Mank,Oscar Isaac,George Russell,#DragonAgeDay,FNCS,#FridayFeeling,Kid of the Year,Big Mouth,York Region,Cullen,Majah,Solid Snake,Big Boss,#NoEncampmentEvictions,Liquid

# %%
print(( '='*10,'intersection of world and us'))
print((trends_set['world'].intersection(trends_set['us'])))

print(('='*10,'intersection of us and Calgary'))
print((trends_set['Calgary'].intersection(trends_set['us'])))
# Out:
# ('==========', 'intersection of world and us')
# {'#NationalCatDay', 'pewds', 'Willock', 'Davies', 'Paul Rudd', 'La Russa', 'Miracle Whip', 'Hahn', 'Corbyn', 'Ivy Park', 'Jerry Reinsdorf', 'White Sox', 'Tottenham', 'Vanity Fair', 'Intercept'}
# ('==========', 'intersection of us and Calgary')
# {'#NationalCatDay', 'Jay Cutler', 'pewds', 'DaBaby', 'Mitchell Miller', 'Davies', 'Vanity Fair', 'Paul Rudd', 'Zlatan', 'Ivy Park', 'Kendrick', 'White Sox', 'Glenn', 'Greenwald', 'Willock', 'Tottenham', 'Intercept'}

# %% [markdown]
# ## Example 5. Collecting search results

# %% [markdown]
# Set the variable `q` to a trending topic,
# or anything else for that matter. The example query below
# was a trending topic when this content was being developed
# and is used throughout the remainder of this chapter

# %%
# You can change this to whatever hashtag you want, but if the tag isn't
# popular enough you might not get back a lot of results
q = "Boba Fett"

number = 100

search_results = tweepy.Cursor(api.search, q=q, lang="en").items(number)

#This will give us an Iterator
print(search_results)

# WE will be looking at the tags "retweeted", "retweet count", 
# and the text we found earlier
tweets = []
retweeted = []
retweet_count = []

for tweet in search_results:
    tweets.append(tweet.text)
    retweet_count.append(tweet.retweet_count)
    # This if/else just checks the number of retweets and defines "rewteeted"
    # based on that value
    if tweet.retweet_count > 0:
        retweeted.append(True)
    else:
        retweeted.append(False)


#tweets
# Out:
# <tweepy.cursor.ItemIterator object at 0x000001C0F8525550>

# %%
# Not necessary, but this does make the data look pretty
import pandas as pd

df = pd.DataFrame({'Tweet':tweets, 'Retweeted':retweeted, "Retweet Count":retweet_count})

df
# Out:
#                                                 Tweet  Retweeted  \
# 0   people are really fat shaming boba fett??? you...      False
# 1   RT @edckbar875: Favreau and Filoni, in just 30...       True
# 2       Boba Fett is back 🔥🔥🔥 https://t.co/NSttr9YuEk      False
# 3   RT @CaptainFireFeet: The #Mandalorian Chapter ...       True
# 4   “What follows is about 15 minutes of outstandi...      False
# ..                                                ...        ...
# 95                                      Boba Fett!!!!      False
# 96  RT @mauldaIorian: mando spoilers / #TheMandalo...       True
# 97  RT @edckbar875: Favreau and Filoni, in just 30...       True
# 98  RT @MattM0411: Boba Fett is a fucking GOAT #Th...       True
# 99  RT @nausic___aa: mando spoilers // #TheMandalo...      False
#
#     Retweet Count
# 0               0
# 1             610
# 2               0
# 3             700
# 4               0
# ..            ...
# 95              0
# 96             72
# 97            610
# 98            103
# 99              0
#
# [100 rows x 3 columns]

# %% [markdown]
# Twitter often returns duplicate results, we can filter them out checking for duplicate texts:

# %%
all_text = []
filtered_tweets = []
for t in tweets:
    if not t in all_text:
        filtered_tweets.append(t)
        all_text.append(t)
#filtered_tweets    
filtered_tweets[0]
# Out:
# 'people are really fat shaming boba fett??? you mfs weird fr'

# %%
#This gives us the number of all of the unique tweets from our search results
print(len(filtered_tweets))
if len(filtered_tweets) < len(tweets):
    print("There were duplicates in our search results!")
# Out:
# 62
# There were duplicates in our search results!

# %% [markdown]
# ## Example 6. Creating a basic frequency distribution from the words in tweets

# %%
from collections import Counter

words = []

for t in tweets:
    for word in t.split():
        words.append(word)
        
c = Counter(words)
c.most_common(10)
# Out:
# [('Boba', 74),
#  ('RT', 66),
#  ('Fett', 59),
#  ('the', 56),
#  ('and', 45),
#  ('in', 39),
#  ('was', 35),
#  ('a', 32),
#  ('-', 30),
#  ('#TheMandalorian', 24)]

# %% [markdown]
# ## Example 7. Create a prettyprint function to display tuples in a nice tabular format

# %%
def prettyprint_counts(label, list_of_tuples):
    print("\n{:^20} | {:^6}".format(label, "Count"))
    print("*"*40)
    for k,v in list_of_tuples:
        print("{:20} | {:>6}".format(k,v))

# %%
for label, data in (('Word', words), 
                    ('Retweet_count', retweet_count)):
    
    c = Counter(data)
    prettyprint_counts(label, c.most_common()[:10])
# Out:
#         Word         | Count
# ****************************************
# Boba                 |     74
# RT                   |     66
# Fett                 |     59
# the                  |     56
# and                  |     45
# in                   |     39
# was                  |     35
# a                    |     32
# -                    |     30
# #TheMandalorian      |     24
#
#    Retweet_count     | Count
# ****************************************
#                    0 |     33
#                  610 |     14
#                  137 |      7
#                  693 |      5
#                    1 |      5
#                  700 |      4
#                  293 |      4
#                  260 |      3
#                    2 |      3
#                   36 |      3

# %% [markdown]
# ## Example 8. Finding the most popular retweets

# %%
# This sets up a filter for our dataset that only leaves data with Retweeted
# marked as true
filter1 = df['Retweeted'] == True

#This is a built in pandas operation that will filter the data given the filter
rt_df = df.where(filter1)

#Now we will have a new df without any NaN values
rt_df = rt_df.dropna()

#The indices will look odd, but this is because it is keeping the old indices
rt_df.head(10)
# Out:
#                                                 Tweet  Retweeted  \
# 1   RT @edckbar875: Favreau and Filoni, in just 30...        1.0
# 3   RT @CaptainFireFeet: The #Mandalorian Chapter ...        1.0
# 7   RT @thchxsenone: cw // #TheMandalorian chapter...        1.0
# 9   RT @GagliardiChase: Boba Fett after cracking o...        1.0
# 10  RT @TheGeekyPeep: Boba Fett: “I’m just a simpl...        1.0
# 14  RT @TheGeekyPeep: Boba Fett: “I’m just a simpl...        1.0
# 15  RT @edckbar875: Favreau and Filoni, in just 30...        1.0
# 16  RT @24Orangemamba: Mando and Fennec watching B...        1.0
# 17  RT @Mericam49: Most people: “WOW Boba Fett’s f...        1.0
# 18  RT @Mericam49: Most people: “WOW Boba Fett’s f...        1.0
#
#     Retweet Count
# 1           610.0
# 3           700.0
# 7           260.0
# 9           293.0
# 10          693.0
# 14          693.0
# 15          610.0
# 16          128.0
# 17          137.0
# 18          137.0

# %% [markdown]
# We can sort this dataframe in descending order of the number of retweets using df.sort_values()

# %%
rt_df_sorted = rt_df.sort_values(by="Retweet Count", ascending=0)

rt_df_sorted.head(5)
# Out:
#                                                 Tweet  Retweeted  \
# 3   RT @CaptainFireFeet: The #Mandalorian Chapter ...        1.0
# 24  RT @CaptainFireFeet: The #Mandalorian Chapter ...        1.0
# 50  RT @CaptainFireFeet: The #Mandalorian Chapter ...        1.0
# 54  RT @CaptainFireFeet: The #Mandalorian Chapter ...        1.0
# 80  RT @TheGeekyPeep: Boba Fett: “I’m just a simpl...        1.0
#
#     Retweet Count
# 3           700.0
# 24          700.0
# 50          700.0
# 54          700.0
# 80          693.0

# %% [markdown]
# We can build another `prettyprint` function to print entire tweets with their retweet count.
#
# We also want to split the text of the tweet in up to 3 lines, if needed.

# %%
### Remember our pretty_print function from above
### We will modify it slightly
def prettyprint_counts_modified(label, list_of_tuples):
    print("\n{:^20} | {:^6}".format(label, "Count"))
    print("*"*40)
    for k,v in list_of_tuples:
        print("{:20} | {:>6}".format(k,v))

# %%
rt_tweets = rt_df_sorted["Tweet"]
rt_re_count = rt_df_sorted["Retweet Count"]

for label, data in (('Tweet', rt_tweets), 
                    ('Retweet_count', rt_re_count)):
    
    c2 = Counter(data)
    prettyprint_counts_modified(label, c2.most_common()[:5])
# Out:
#        Tweet         | Count
# ****************************************
# RT @edckbar875: Favreau and Filoni, in just 30 minutes, made me believe Boba Fett is the badass we’ve been told he was in the past 40 years… |     14
# RT @Mericam49: Most people: “WOW Boba Fett’s fight scene was so cool! What a badass!!”
#
# Me, thinking about how Jango was a foundling and fo… |      7
# RT @TheGeekyPeep: Boba Fett: “I’m just a simple man making his way through the galaxy.”
# Us:
#
# #TheMandalorian https://t.co/RDv2QckjaB |      5
# RT @CaptainFireFeet: The #Mandalorian Chapter 14 was lit. They brought in Boba Fett and everything https://t.co/mNmNgiScEr |      4
# RT @GagliardiChase: Boba Fett after cracking open yet another stormtooper helmet #mandalorian https://t.co/9upnhQy7vk |      4
#
#    Retweet_count     | Count
# ****************************************
#                610.0 |     14
#                137.0 |      7
#                693.0 |      5
#                  1.0 |      5
#                700.0 |      4
