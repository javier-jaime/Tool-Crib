# %% [markdown]
# <a href="https://colab.research.google.com/github/javier-jaime/Tool-Crib/blob/master/Colab/SVRP_PYOMO_AbstractModel.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Stochastic Optimization for Vehicle Routing Problem with PYOMO

# %% [markdown]
# ### Import Necessary Libraries

# %%
# !pip install pyomo
# !sudo apt-get install glpk-utils

from pyomo.environ import *
from pyomo import environ as pe
# from coopr.pyomo import *
#from coopr.opt.base import solver
from pyomo.opt import *

from google.colab import drive
from google.colab import files

import scipy
import numpy
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: pyomo in /usr/local/lib/python3.7/dist-packages (6.4.2)
# Requirement already satisfied: ply in /usr/local/lib/python3.7/dist-packages (from pyomo) (3.11)
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# glpk-utils is already the newest version (4.65-1).
# The following package was automatically installed and is no longer required:
#   libnvidia-common-460
# Use 'sudo apt autoremove' to remove it.
# 0 upgraded, 0 newly installed, 0 to remove and 4 not upgraded.

# %%
# Mount Google Drive

drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# Import Data File
# !cp drive/MyDrive/Colab_Data/svrp_data.dat "/content/"

# %% [markdown]
# ### Abstract Model

# %%
# AbstractModel is where data values are supplied in a data file

model = AbstractModel()

# %%
# Define sets

model.I = Set() #node
model.J = Set()
model.S = Set() #source node
model.D = Set() #demand node

# %%
# Data_deterministic

model.Arc = Param(model.I, model.J) #arc available
model.Rev = Param(model.I, model.J) #arc revenue
model.Cost = Param(model.I, model.J) #arc cost
model.B = Param()

# %%
#Data_stochastic

model.ArcDemand = Param(model.I, model.J) #arc demand

# %%
# Variables

model.X_WS = Param(model.S)
model.X_EV = Param(model.S)
#model.X_RP = Param(initialize=lambda m: model.S[value(model.S)])
model.X = Var(model.S, bounds=(0.0, model.B))
model.Y = Var(model.I, model.J, bounds=(0.0, model.B))
model.Z = Var(model.I, model.J, bounds=(0.0, None))

model.FirstStageProfit = Var()
model.SecondStageProfit = Var()

# %%
# Constraints

def vehicle_num_cap_rule(model):
    return sum(model.X[s] for s in model.S) <= model.B
model.VehicleNumCapRule = Constraint(rule=vehicle_num_cap_rule)


def vehicle_assigned_cap_rule(model,s):
    return sum(model.Y[s,j] for j in model.J if model.Arc[s,j]>=1) == model.X[s]
model.RequiredDemandRule = Constraint(model.S, rule=vehicle_assigned_cap_rule)

def flow_balance_rule(model,d):
    return (sum(model.Y[i,d] for i in model.I if model.Arc[i,d]>=1) - sum(model.Y[d,i] for i in model.I if model.Arc[d,i]>=1)) == 0.0
model.FlowBalanceRule = Constraint(model.D, rule=flow_balance_rule)

def overage_rule(model,i,j):
    return model.Y[i,j] - model.ArcDemand[i,j] <= model.Z[i,j]
model.OverageRule = Constraint(model.I, model.J, rule=overage_rule)

def y_rule(model,i,j):
    return (0.0, model.Y[i,j], model.Arc[i,j]*51)
model.YRule = Constraint(model.I, model.J, rule=y_rule)

#NOTE: (Part H) We have added a constraint to fix X at RP
##def x_fix_rule(model,s):
##    return model.X[s] == model.X_RP[s]
##model.XFixRule = Constraint(model.S, rule=x_fix_rule)

# %%
# Stage-specific cost computations

def first_stage_profit_rule(model):
    return model.FirstStageProfit == 0.0
model.ComputeFirstStageProfit = Constraint(rule=first_stage_profit_rule)

def second_stage_profit_rule(model):
    return model.SecondStageProfit - sum(sum(model.Rev[i,j] * model.Y[i,j] - (model.Rev[i,j] + model.Cost[i,j])* model.Z[i,j] \
                                           for i in model.I) for j in model.J) == 0.0
model.ComputeSecondStageProfit = Constraint(rule=second_stage_profit_rule)

# %%
# Objective

def total_profit_rule(model):
    return (model.FirstStageProfit + model.SecondStageProfit)

model.Total_Profit_Objective = Objective(rule=total_profit_rule, sense=maximize)

# %%
# Solve WS for given number of sample realizations with fixed X at X_WS
numSamples=100
numX=5
optVal=numpy.array([0 for i in range(numSamples)])

# %%
for i in range(numSamples):
    datafile='svrp_data.dat'
    #datafile = '../drive/MyDrive/Colab_Data/Scenario' + str(i+1) + '.dat'
    instance = model.create_instance(datafile)
    opt= pe.SolverFactory("glpk")
    results = opt.solve(instance, tee=True)
    instance.solutions.store_to(results)
    results.write()
    #instance.pprint()
    #instance.display()
    optVal[i] = value(instance.Total_Profit_Objective)
# Out:
# Streaming output truncated to the last 5000 lines.
#       Value: 1.5
#     Y[13,17]:
#       Value: 4.65
#     Y[13,18]:
#       Value: 1.85
#     Y[14,17]:
#       Value: 2.05
#     Y[14,18]:
#       Value: 2.95
#     Y[14,19]:
#       Value: 1.1
#     Y[15,20]:
#       Value: 7.15
#     Y[16,20]:
#       Value: 9.9
#     Y[17,20]:
#       Value: 10.55
#     Y[18,20]:
#       Value: 6.7
#     Y[19,20]:
#       Value: 3.1
#     Y[2,11]:
#       Value: 2.9
#     Y[2,12]:
#       Value: 2.05
#     Y[2,6]:
#       Value: 1.25
#     Y[2,7]:
#       Value: 4.45
#     Y[2,8]:
#       Value: 1.05
#     Y[3,12]:
#       Value: 1.1
#     Y[3,7]:
#       Value: 0.9
#     Y[3,8]:
#       Value: 1.25
#     Y[3,9]:
#       Value: 1.85
#     Y[4,10]:
#       Value: 2.05
#     Y[4,13]:
#       Value: 2.1
#     Y[4,8]:
#       Value: 1.25
#     Y[4,9]:
#       Value: 2.9
#     Y[5,10]:
#       Value: 2.05
#     Y[5,14]:
#       Value: 2.9
#     Y[6,12]:
#       Value: 1.75
#     Y[6,15]:
#       Value: 1.5
#     Y[6,16]:
#       Value: 1.1
#     Y[7,11]:
#       Value: 1.25
#     Y[7,12]:
#       Value: 2.1
#     Y[7,13]:
#       Value: 2.9
#     Y[8,13]:
#       Value: 1.25
#     Y[8,16]:
#       Value: 2.05
#     Y[8,17]:
#       Value: 2.1
#     Y[9,13]:
#       Value: 1.75
#     Y[9,14]:
#       Value: 1.1
#     Y[9,18]:
#       Value: 1.9
#     Z[1,6]:
#       Value: 0.2
#     Z[10,19]:
#       Value: 1.1
#     Z[11,15]:
#       Value: 2.3
#     Z[12,16]:
#       Value: 2.5
#     Z[13,17]:
#       Value: 3.1
#     Z[14,18]:
#       Value: 1.7
#     Z[15,20]:
#       Value: 7.15
#     Z[16,20]:
#       Value: 9.9
#     Z[17,20]:
#       Value: 10.55
#     Z[18,20]:
#       Value: 6.7
#     Z[19,20]:
#       Value: 3.1
#     Z[2,7]:
#       Value: 2.9
#     Z[2,8]:
#       Value: 0.15
#     Z[9,18]:
#       Value: 0.15
#   Constraint: No values
# GLPSOL: GLPK LP/MIP Solver, v4.65
# Parameter(s) specified in the command line:
#  --write /tmp/tmp9m78_eeu.glpk.raw --wglp /tmp/tmpa9cj4xwg.glpk.glp --cpxlp
#  /tmp/tmpstnk50ci.pyomo.lp
# Reading problem data from '/tmp/tmpstnk50ci.pyomo.lp'...
# 1223 rows, 808 columns, 1802 non-zeros
# 6288 lines were read
# Writing problem data to '/tmp/tmpa9cj4xwg.glpk.glp'...
# 5447 lines were written
# GLPK Simplex Optimizer, v4.65
# 1223 rows, 808 columns, 1802 non-zeros
# Preprocessing...
# 66 rows, 97 columns, 194 non-zeros
# Scaling...
#  A: min|aij| =  1.000e+00  max|aij| =  1.000e+00  ratio =  1.000e+00
# Problem data seem to be well scaled
# Constructing initial basis...
# Size of triangular part is 66
# *     0: obj =  -0.000000000e+00 inf =   0.000e+00 (28)
# *    50: obj =   1.925580000e+04 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# Time used:   0.0 secs
# Memory used: 0.8 Mb (825388 bytes)
# Writing basic solution to '/tmp/tmp9m78_eeu.glpk.raw'...
# 2040 lines were written
# # ==========================================================
# # = Solver Results                                         =
# # ==========================================================
# # ----------------------------------------------------------
# #   Problem Information
# # ----------------------------------------------------------
# Problem:
# - Name: unknown
#   Lower bound: 19255.8
#   Upper bound: 19255.8
#   Number of objectives: 1
#   Number of constraints: 1223
#   Number of variables: 808
#   Number of nonzeros: 1802
#   Sense: maximize
# # ----------------------------------------------------------
# #   Solver Information
# # ----------------------------------------------------------
# Solver:
# - Status: ok
#   Termination condition: optimal
#   Statistics:
#     Branch and bound:
#       Number of bounded subproblems: 0
#       Number of created subproblems: 0
#   Error rc: 0
#   Time: 0.024219751358032227
# # ----------------------------------------------------------
# #   Solution Information
# # ----------------------------------------------------------
# Solution:
# - number of solutions: 1
#   number of solutions displayed: 1
# - Gap: 0.0
#   Status: feasible
#   Message: None
#   Objective:
#     Total_Profit_Objective:
#       Value: 19255.8
#   Variable:
#     SecondStageProfit:
#       Value: 19255.8
#     X[1]:
#       Value: 7.35
#     X[2]:
#       Value: 11.7
#     X[3]:
#       Value: 5.1
#     X[4]:
#       Value: 8.3
#     X[5]:
#       Value: 4.95
#     Y[1,11]:
#       Value: 1.5
#     Y[1,6]:
#       Value: 3.1
#     Y[1,7]:
#       Value: 0.9
#     Y[1,8]:
#       Value: 1.85
#     Y[10,14]:
#       Value: 2.1
#     Y[10,19]:
#       Value: 2
#     Y[11,15]:
#       Value: 3.8
#     Y[11,16]:
#       Value: 1.85
#     Y[12,15]:
#       Value: 1.85
#     Y[12,16]:
#       Value: 3.4
#     Y[12,17]:
#       Value: 1.75
#     Y[13,16]:
#       Value: 1.5
#     Y[13,17]:
#       Value: 4.65
#     Y[13,18]:
#       Value: 1.85
#     Y[14,17]:
#       Value: 2.05
#     Y[14,18]:
#       Value: 2.95
#     Y[14,19]:
#       Value: 1.1
#     Y[15,20]:
#       Value: 7.15
#     Y[16,20]:
#       Value: 9.9
#     Y[17,20]:
#       Value: 10.55
#     Y[18,20]:
#       Value: 6.7
#     Y[19,20]:
#       Value: 3.1
#     Y[2,11]:
#       Value: 2.9
#     Y[2,12]:
#       Value: 2.05
#     Y[2,6]:
#       Value: 1.25
#     Y[2,7]:
#       Value: 4.45
#     Y[2,8]:
#       Value: 1.05
#     Y[3,12]:
#       Value: 1.1
#     Y[3,7]:
#       Value: 0.9
#     Y[3,8]:
#       Value: 1.25
#     Y[3,9]:
#       Value: 1.85
#     Y[4,10]:
#       Value: 2.05
#     Y[4,13]:
#       Value: 2.1
#     Y[4,8]:
#       Value: 1.25
#     Y[4,9]:
#       Value: 2.9
#     Y[5,10]:
#       Value: 2.05
#     Y[5,14]:
#       Value: 2.9
#     Y[6,12]:
#       Value: 1.75
#     Y[6,15]:
#       Value: 1.5
#     Y[6,16]:
#       Value: 1.1
#     Y[7,11]:
#       Value: 1.25
#     Y[7,12]:
#       Value: 2.1
#     Y[7,13]:
#       Value: 2.9
#     Y[8,13]:
#       Value: 1.25
#     Y[8,16]:
#       Value: 2.05
#     Y[8,17]:
#       Value: 2.1
#     Y[9,13]:
#       Value: 1.75
#     Y[9,14]:
#       Value: 1.1
#     Y[9,18]:
#       Value: 1.9
#     Z[1,6]:
#       Value: 0.2
#     Z[10,19]:
#       Value: 1.1
#     Z[11,15]:
#       Value: 2.3
#     Z[12,16]:
#       Value: 2.5
#     Z[13,17]:
#       Value: 3.1
#     Z[14,18]:
#       Value: 1.7
#     Z[15,20]:
#       Value: 7.15
#     Z[16,20]:
#       Value: 9.9
#     Z[17,20]:
#       Value: 10.55
#     Z[18,20]:
#       Value: 6.7
#     Z[19,20]:
#       Value: 3.1
#     Z[2,7]:
#       Value: 2.9
#     Z[2,8]:
#       Value: 0.15
#     Z[9,18]:
#       Value: 0.15
#   Constraint: No values
# GLPSOL: GLPK LP/MIP Solver, v4.65
# Parameter(s) specified in the command line:
#  --write /tmp/tmpt0qanmn_.glpk.raw --wglp /tmp/tmp2er42p4i.glpk.glp --cpxlp
#  /tmp/tmpwvmgq8a9.pyomo.lp
# Reading problem data from '/tmp/tmpwvmgq8a9.pyomo.lp'...
# 1223 rows, 808 columns, 1802 non-zeros
# 6288 lines were read
# Writing problem data to '/tmp/tmp2er42p4i.glpk.glp'...
# 5447 lines were written
# GLPK Simplex Optimizer, v4.65
# 1223 rows, 808 columns, 1802 non-zeros
# Preprocessing...
# 66 rows, 97 columns, 194 non-zeros
# Scaling...
#  A: min|aij| =  1.000e+00  max|aij| =  1.000e+00  ratio =  1.000e+00
# Problem data seem to be well scaled
# Constructing initial basis...
# Size of triangular part is 66
# *     0: obj =  -0.000000000e+00 inf =   0.000e+00 (28)
# *    50: obj =   1.925580000e+04 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# Time used:   0.0 secs
# Memory used: 0.8 Mb (825388 bytes)
# Writing basic solution to '/tmp/tmpt0qanmn_.glpk.raw'...
# 2040 lines were written
# # ==========================================================
# # = Solver Results                                         =
# # ==========================================================
# # ----------------------------------------------------------
# #   Problem Information
# # ----------------------------------------------------------
# Problem:
# - Name: unknown
#   Lower bound: 19255.8
#   Upper bound: 19255.8
#   Number of objectives: 1
#   Number of constraints: 1223
#   Number of variables: 808
#   Number of nonzeros: 1802
#   Sense: maximize
# # ----------------------------------------------------------
# #   Solver Information
# # ----------------------------------------------------------
# Solver:
# - Status: ok
#   Termination condition: optimal
#   Statistics:
#     Branch and bound:
#       Number of bounded subproblems: 0
#       Number of created subproblems: 0
#   Error rc: 0
#   Time: 0.034653663635253906
# # ----------------------------------------------------------
# #   Solution Information
# # ----------------------------------------------------------
# Solution:
# - number of solutions: 1
#   number of solutions displayed: 1
# - Gap: 0.0
#   Status: feasible
#   Message: None
#   Objective:
#     Total_Profit_Objective:
#       Value: 19255.8
#   Variable:
#     SecondStageProfit:
#       Value: 19255.8
#     X[1]:
#       Value: 7.35
#     X[2]:
#       Value: 11.7
#     X[3]:
#       Value: 5.1
#     X[4]:
#       Value: 8.3
#     X[5]:
#       Value: 4.95
#     Y[1,11]:
#       Value: 1.5
#     Y[1,6]:
#       Value: 3.1
#     Y[1,7]:
#       Value: 0.9
#     Y[1,8]:
#       Value: 1.85
#     Y[10,14]:
#       Value: 2.1
#     Y[10,19]:
#       Value: 2
#     Y[11,15]:
#       Value: 3.8
#     Y[11,16]:
#       Value: 1.85
#     Y[12,15]:
#       Value: 1.85
#     Y[12,16]:
#       Value: 3.4
#     Y[12,17]:
#       Value: 1.75
#     Y[13,16]:
#       Value: 1.5
#     Y[13,17]:
#       Value: 4.65
#     Y[13,18]:
#       Value: 1.85
#     Y[14,17]:
#       Value: 2.05
#     Y[14,18]:
#       Value: 2.95
#     Y[14,19]:
#       Value: 1.1
#     Y[15,20]:
#       Value: 7.15
#     Y[16,20]:
#       Value: 9.9
#     Y[17,20]:
#       Value: 10.55
#     Y[18,20]:
#       Value: 6.7
#     Y[19,20]:
#       Value: 3.1
#     Y[2,11]:
#       Value: 2.9
#     Y[2,12]:
#       Value: 2.05
#     Y[2,6]:
#       Value: 1.25
#     Y[2,7]:
#       Value: 4.45
#     Y[2,8]:
#       Value: 1.05
#     Y[3,12]:
#       Value: 1.1
#     Y[3,7]:
#       Value: 0.9
#     Y[3,8]:
#       Value: 1.25
#     Y[3,9]:
#       Value: 1.85
#     Y[4,10]:
#       Value: 2.05
#     Y[4,13]:
#       Value: 2.1
#     Y[4,8]:
#       Value: 1.25
#     Y[4,9]:
#       Value: 2.9
#     Y[5,10]:
#       Value: 2.05
#     Y[5,14]:
#       Value: 2.9
#     Y[6,12]:
#       Value: 1.75
#     Y[6,15]:
#       Value: 1.5
#     Y[6,16]:
#       Value: 1.1
#     Y[7,11]:
#       Value: 1.25
#     Y[7,12]:
#       Value: 2.1
#     Y[7,13]:
#       Value: 2.9
#     Y[8,13]:
#       Value: 1.25
#     Y[8,16]:
#       Value: 2.05
#     Y[8,17]:
#       Value: 2.1
#     Y[9,13]:
#       Value: 1.75
#     Y[9,14]:
#       Value: 1.1
#     Y[9,18]:
#       Value: 1.9
#     Z[1,6]:
#       Value: 0.2
#     Z[10,19]:
#       Value: 1.1
#     Z[11,15]:
#       Value: 2.3
#     Z[12,16]:
#       Value: 2.5
#     Z[13,17]:
#       Value: 3.1
#     Z[14,18]:
#       Value: 1.7
#     Z[15,20]:
#       Value: 7.15
#     Z[16,20]:
#       Value: 9.9
#     Z[17,20]:
#       Value: 10.55
#     Z[18,20]:
#       Value: 6.7
#     Z[19,20]:
#       Value: 3.1
#     Z[2,7]:
#       Value: 2.9
#     Z[2,8]:
#       Value: 0.15
#     Z[9,18]:
#       Value: 0.15
#   Constraint: No values
# GLPSOL: GLPK LP/MIP Solver, v4.65
# Parameter(s) specified in the command line:
#  --write /tmp/tmp2o0t6lum.glpk.raw --wglp /tmp/tmpungiyvok.glpk.glp --cpxlp
#  /tmp/tmpehidp5_5.pyomo.lp
# Reading problem data from '/tmp/tmpehidp5_5.pyomo.lp'...
# 1223 rows, 808 columns, 1802 non-zeros
# 6288 lines were read
# Writing problem data to '/tmp/tmpungiyvok.glpk.glp'...
# 5447 lines were written
# GLPK Simplex Optimizer, v4.65
# 1223 rows, 808 columns, 1802 non-zeros
# Preprocessing...
# 66 rows, 97 columns, 194 non-zeros
# Scaling...
#  A: min|aij| =  1.000e+00  max|aij| =  1.000e+00  ratio =  1.000e+00
# Problem data seem to be well scaled
# Constructing initial basis...
# Size of triangular part is 66
# *     0: obj =  -0.000000000e+00 inf =   0.000e+00 (28)
# *    50: obj =   1.925580000e+04 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# Time used:   0.0 secs
# Memory used: 0.8 Mb (825388 bytes)
# Writing basic solution to '/tmp/tmp2o0t6lum.glpk.raw'...
# 2040 lines were written
# # ==========================================================
# # = Solver Results                                         =
# # ==========================================================
# # ----------------------------------------------------------
# #   Problem Information
# # ----------------------------------------------------------
# Problem:
# - Name: unknown
#   Lower bound: 19255.8
#   Upper bound: 19255.8
#   Number of objectives: 1
#   Number of constraints: 1223
#   Number of variables: 808
#   Number of nonzeros: 1802
#   Sense: maximize
# # ----------------------------------------------------------
# #   Solver Information
# # ----------------------------------------------------------
# Solver:
# - Status: ok
#   Termination condition: optimal
#   Statistics:
#     Branch and bound:
#       Number of bounded subproblems: 0
#       Number of created subproblems: 0
#   Error rc: 0
#   Time: 0.024776697158813477
# # ----------------------------------------------------------
# #   Solution Information
# # ----------------------------------------------------------
# Solution:
# - number of solutions: 1
#   number of solutions displayed: 1
# - Gap: 0.0
#   Status: feasible
#   Message: None
#   Objective:
#     Total_Profit_Objective:
#       Value: 19255.8
#   Variable:
#     SecondStageProfit:
#       Value: 19255.8
#     X[1]:
#       Value: 7.35
#     X[2]:
#       Value: 11.7
#     X[3]:
#       Value: 5.1
#     X[4]:
#       Value: 8.3
#     X[5]:
#       Value: 4.95
#     Y[1,11]:
#       Value: 1.5
#     Y[1,6]:
#       Value: 3.1
#     Y[1,7]:
#       Value: 0.9
#     Y[1,8]:
#       Value: 1.85
#     Y[10,14]:
#       Value: 2.1
#     Y[10,19]:
#       Value: 2
#     Y[11,15]:
#       Value: 3.8
#     Y[11,16]:
#       Value: 1.85
#     Y[12,15]:
#       Value: 1.85
#     Y[12,16]:
#       Value: 3.4
#     Y[12,17]:
#       Value: 1.75
#     Y[13,16]:
#       Value: 1.5
#     Y[13,17]:
#       Value: 4.65
#     Y[13,18]:
#       Value: 1.85
#     Y[14,17]:
#       Value: 2.05
#     Y[14,18]:
#       Value: 2.95
#     Y[14,19]:
#       Value: 1.1
#     Y[15,20]:
#       Value: 7.15
#     Y[16,20]:
#       Value: 9.9
#     Y[17,20]:
#       Value: 10.55
#     Y[18,20]:
#       Value: 6.7
#     Y[19,20]:
#       Value: 3.1
#     Y[2,11]:
#       Value: 2.9
#     Y[2,12]:
#       Value: 2.05
#     Y[2,6]:
#       Value: 1.25
#     Y[2,7]:
#       Value: 4.45
#     Y[2,8]:
#       Value: 1.05
#     Y[3,12]:
#       Value: 1.1
#     Y[3,7]:
#       Value: 0.9
#     Y[3,8]:
#       Value: 1.25
#     Y[3,9]:
#       Value: 1.85
#     Y[4,10]:
#       Value: 2.05
#     Y[4,13]:
#       Value: 2.1
#     Y[4,8]:
#       Value: 1.25
#     Y[4,9]:
#       Value: 2.9
#     Y[5,10]:
#       Value: 2.05
#     Y[5,14]:
#       Value: 2.9
#     Y[6,12]:
#       Value: 1.75
#     Y[6,15]:
#       Value: 1.5
#     Y[6,16]:
#       Value: 1.1
#     Y[7,11]:
#       Value: 1.25
#     Y[7,12]:
#       Value: 2.1
#     Y[7,13]:
#       Value: 2.9
#     Y[8,13]:
#       Value: 1.25
#     Y[8,16]:
#       Value: 2.05
#     Y[8,17]:
#       Value: 2.1
#     Y[9,13]:
#       Value: 1.75
#     Y[9,14]:
#       Value: 1.1
#     Y[9,18]:
#       Value: 1.9
#     Z[1,6]:
#       Value: 0.2
#     Z[10,19]:
#       Value: 1.1
#     Z[11,15]:
#       Value: 2.3
#     Z[12,16]:
#       Value: 2.5
#     Z[13,17]:
#       Value: 3.1
#     Z[14,18]:
#       Value: 1.7
#     Z[15,20]:
#       Value: 7.15
#     Z[16,20]:
#       Value: 9.9
#     Z[17,20]:
#       Value: 10.55
#     Z[18,20]:
#       Value: 6.7
#     Z[19,20]:
#       Value: 3.1
#     Z[2,7]:
#       Value: 2.9
#     Z[2,8]:
#       Value: 0.15
#     Z[9,18]:
#       Value: 0.15
#   Constraint: No values
# GLPSOL: GLPK LP/MIP Solver, v4.65
# Parameter(s) specified in the command line:
#  --write /tmp/tmpqyp_oifj.glpk.raw --wglp /tmp/tmpe_p6s7tp.glpk.glp --cpxlp
#  /tmp/tmp6dqgwn2l.pyomo.lp
# Reading problem data from '/tmp/tmp6dqgwn2l.pyomo.lp'...
# 1223 rows, 808 columns, 1802 non-zeros
# 6288 lines were read
# Writing problem data to '/tmp/tmpe_p6s7tp.glpk.glp'...
# 5447 lines were written
# GLPK Simplex Optimizer, v4.65
# 1223 rows, 808 columns, 1802 non-zeros
# Preprocessing...
# 66 rows, 97 columns, 194 non-zeros
# Scaling...
#  A: min|aij| =  1.000e+00  max|aij| =  1.000e+00  ratio =  1.000e+00
# Problem data seem to be well scaled
# Constructing initial basis...
# Size of triangular part is 66
# *     0: obj =  -0.000000000e+00 inf =   0.000e+00 (28)
# *    50: obj =   1.925580000e+04 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# Time used:   0.0 secs
# Memory used: 0.8 Mb (825388 bytes)
# Writing basic solution to '/tmp/tmpqyp_oifj.glpk.raw'...
# 2040 lines were written
# # ==========================================================
# # = Solver Results                                         =
# # ==========================================================
# # ----------------------------------------------------------
# #   Problem Information
# # ----------------------------------------------------------
# Problem:
# - Name: unknown
#   Lower bound: 19255.8
#   Upper bound: 19255.8
#   Number of objectives: 1
#   Number of constraints: 1223
#   Number of variables: 808
#   Number of nonzeros: 1802
#   Sense: maximize
# # ----------------------------------------------------------
# #   Solver Information
# # ----------------------------------------------------------
# Solver:
# - Status: ok
#   Termination condition: optimal
#   Statistics:
#     Branch and bound:
#       Number of bounded subproblems: 0
#       Number of created subproblems: 0
#   Error rc: 0
#   Time: 0.03139090538024902
# # ----------------------------------------------------------
# #   Solution Information
# # ----------------------------------------------------------
# Solution:
# - number of solutions: 1
#   number of solutions displayed: 1
# - Gap: 0.0
#   Status: feasible
#   Message: None
#   Objective:
#     Total_Profit_Objective:
#       Value: 19255.8
#   Variable:
#     SecondStageProfit:
#       Value: 19255.8
#     X[1]:
#       Value: 7.35
#     X[2]:
#       Value: 11.7
#     X[3]:
#       Value: 5.1
#     X[4]:
#       Value: 8.3
#     X[5]:
#       Value: 4.95
#     Y[1,11]:
#       Value: 1.5
#     Y[1,6]:
#       Value: 3.1
#     Y[1,7]:
#       Value: 0.9
#     Y[1,8]:
#       Value: 1.85
#     Y[10,14]:
#       Value: 2.1
#     Y[10,19]:
#       Value: 2
#     Y[11,15]:
#       Value: 3.8
#     Y[11,16]:
#       Value: 1.85
#     Y[12,15]:
#       Value: 1.85
#     Y[12,16]:
#       Value: 3.4
#     Y[12,17]:
#       Value: 1.75
#     Y[13,16]:
#       Value: 1.5
#     Y[13,17]:
#       Value: 4.65
#     Y[13,18]:
#       Value: 1.85
#     Y[14,17]:
#       Value: 2.05
#     Y[14,18]:
#       Value: 2.95
#     Y[14,19]:
#       Value: 1.1
#     Y[15,20]:
#       Value: 7.15
#     Y[16,20]:
#       Value: 9.9
#     Y[17,20]:
#       Value: 10.55
#     Y[18,20]:
#       Value: 6.7
#     Y[19,20]:
#       Value: 3.1
#     Y[2,11]:
#       Value: 2.9
#     Y[2,12]:
#       Value: 2.05
#     Y[2,6]:
#       Value: 1.25
#     Y[2,7]:
#       Value: 4.45
#     Y[2,8]:
#       Value: 1.05
#     Y[3,12]:
#       Value: 1.1
#     Y[3,7]:
#       Value: 0.9
#     Y[3,8]:
#       Value: 1.25
#     Y[3,9]:
#       Value: 1.85
#     Y[4,10]:
#       Value: 2.05
#     Y[4,13]:
#       Value: 2.1
#     Y[4,8]:
#       Value: 1.25
#     Y[4,9]:
#       Value: 2.9
#     Y[5,10]:
#       Value: 2.05
#     Y[5,14]:
#       Value: 2.9
#     Y[6,12]:
#       Value: 1.75
#     Y[6,15]:
#       Value: 1.5
#     Y[6,16]:
#       Value: 1.1
#     Y[7,11]:
#       Value: 1.25
#     Y[7,12]:
#       Value: 2.1
#     Y[7,13]:
#       Value: 2.9
#     Y[8,13]:
#       Value: 1.25
#     Y[8,16]:
#       Value: 2.05
#     Y[8,17]:
#       Value: 2.1
#     Y[9,13]:
#       Value: 1.75
#     Y[9,14]:
#       Value: 1.1
#     Y[9,18]:
#       Value: 1.9
#     Z[1,6]:
#       Value: 0.2
#     Z[10,19]:
#       Value: 1.1
#     Z[11,15]:
#       Value: 2.3
#     Z[12,16]:
#       Value: 2.5
#     Z[13,17]:
#       Value: 3.1
#     Z[14,18]:
#       Value: 1.7
#     Z[15,20]:
#       Value: 7.15
#     Z[16,20]:
#       Value: 9.9
#     Z[17,20]:
#       Value: 10.55
#     Z[18,20]:
#       Value: 6.7
#     Z[19,20]:
#       Value: 3.1
#     Z[2,7]:
#       Value: 2.9
#     Z[2,8]:
#       Value: 0.15
#     Z[9,18]:
#       Value: 0.15
#   Constraint: No values
# GLPSOL: GLPK LP/MIP Solver, v4.65
# Parameter(s) specified in the command line:
#  --write /tmp/tmpzr5vena6.glpk.raw --wglp /tmp/tmpei77fuo1.glpk.glp --cpxlp
#  /tmp/tmp4j3wwlrp.pyomo.lp
# Reading problem data from '/tmp/tmp4j3wwlrp.pyomo.lp'...
# 1223 rows, 808 columns, 1802 non-zeros
# 6288 lines were read
# Writing problem data to '/tmp/tmpei77fuo1.glpk.glp'...
# 5447 lines were written
# GLPK Simplex Optimizer, v4.65
# 1223 rows, 808 columns, 1802 non-zeros
# Preprocessing...
# 66 rows, 97 columns, 194 non-zeros
# Scaling...
#  A: min|aij| =  1.000e+00  max|aij| =  1.000e+00  ratio =  1.000e+00
# Problem data seem to be well scaled
# Constructing initial basis...
# Size of triangular part is 66
# *     0: obj =  -0.000000000e+00 inf =   0.000e+00 (28)
# *    50: obj =   1.925580000e+04 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# Time used:   0.0 secs
# Memory used: 0.8 Mb (825388 bytes)
# Writing basic solution to '/tmp/tmpzr5vena6.glpk.raw'...
# 2040 lines were written
# # ==========================================================
# # = Solver Results                                         =
# # ==========================================================
# # ----------------------------------------------------------
# #   Problem Information
# # ----------------------------------------------------------
# Problem:
# - Name: unknown
#   Lower bound: 19255.8
#   Upper bound: 19255.8
#   Number of objectives: 1
#   Number of constraints: 1223
#   Number of variables: 808
#   Number of nonzeros: 1802
#   Sense: maximize
# # ----------------------------------------------------------
# #   Solver Information
# # ----------------------------------------------------------
# Solver:
# - Status: ok
#   Termination condition: optimal
#   Statistics:
#     Branch and bound:
#       Number of bounded subproblems: 0
#       Number of created subproblems: 0
#   Error rc: 0
#   Time: 0.02480006217956543
# # ----------------------------------------------------------
# #   Solution Information
# # ----------------------------------------------------------
# Solution:
# - number of solutions: 1
#   number of solutions displayed: 1
# - Gap: 0.0
#   Status: feasible
#   Message: None
#   Objective:
#     Total_Profit_Objective:
#       Value: 19255.8
#   Variable:
#     SecondStageProfit:
#       Value: 19255.8
#     X[1]:
#       Value: 7.35
#     X[2]:
#       Value: 11.7
#     X[3]:
#       Value: 5.1
#     X[4]:
#       Value: 8.3
#     X[5]:
#       Value: 4.95
#     Y[1,11]:
#       Value: 1.5
#     Y[1,6]:
#       Value: 3.1
#     Y[1,7]:
#       Value: 0.9
#     Y[1,8]:
#       Value: 1.85
#     Y[10,14]:
#       Value: 2.1
#     Y[10,19]:
#       Value: 2
#     Y[11,15]:
#       Value: 3.8
#     Y[11,16]:
#       Value: 1.85
#     Y[12,15]:
#       Value: 1.85
#     Y[12,16]:
#       Value: 3.4
#     Y[12,17]:
#       Value: 1.75
#     Y[13,16]:
#       Value: 1.5
#     Y[13,17]:
#       Value: 4.65
#     Y[13,18]:
#       Value: 1.85
#     Y[14,17]:
#       Value: 2.05
#     Y[14,18]:
#       Value: 2.95
#     Y[14,19]:
#       Value: 1.1
#     Y[15,20]:
#       Value: 7.15
#     Y[16,20]:
#       Value: 9.9
#     Y[17,20]:
#       Value: 10.55
#     Y[18,20]:
#       Value: 6.7
#     Y[19,20]:
#       Value: 3.1
#     Y[2,11]:
#       Value: 2.9
#     Y[2,12]:
#       Value: 2.05
#     Y[2,6]:
#       Value: 1.25
#     Y[2,7]:
#       Value: 4.45
#     Y[2,8]:
#       Value: 1.05
#     Y[3,12]:
#       Value: 1.1
#     Y[3,7]:
#       Value: 0.9
#     Y[3,8]:
#       Value: 1.25
#     Y[3,9]:
#       Value: 1.85
#     Y[4,10]:
#       Value: 2.05
#     Y[4,13]:
#       Value: 2.1
#     Y[4,8]:
#       Value: 1.25
#     Y[4,9]:
#       Value: 2.9
#     Y[5,10]:
#       Value: 2.05
#     Y[5,14]:
#       Value: 2.9
#     Y[6,12]:
#       Value: 1.75
#     Y[6,15]:
#       Value: 1.5
#     Y[6,16]:
#       Value: 1.1
#     Y[7,11]:
#       Value: 1.25
#     Y[7,12]:
#       Value: 2.1
#     Y[7,13]:
#       Value: 2.9
#     Y[8,13]:
#       Value: 1.25
#     Y[8,16]:
#       Value: 2.05
#     Y[8,17]:
#       Value: 2.1
#     Y[9,13]:
#       Value: 1.75
#     Y[9,14]:
#       Value: 1.1
#     Y[9,18]:
#       Value: 1.9
#     Z[1,6]:
#       Value: 0.2
#     Z[10,19]:
#       Value: 1.1
#     Z[11,15]:
#       Value: 2.3
#     Z[12,16]:
#       Value: 2.5
#     Z[13,17]:
#       Value: 3.1
#     Z[14,18]:
#       Value: 1.7
#     Z[15,20]:
#       Value: 7.15
#     Z[16,20]:
#       Value: 9.9
#     Z[17,20]:
#       Value: 10.55
#     Z[18,20]:
#       Value: 6.7
#     Z[19,20]:
#       Value: 3.1
#     Z[2,7]:
#       Value: 2.9
#     Z[2,8]:
#       Value: 0.15
#     Z[9,18]:
#       Value: 0.15
#   Constraint: No values
# GLPSOL: GLPK LP/MIP Solver, v4.65
# Parameter(s) specified in the command line:
#  --write /tmp/tmp6a5gt3uf.glpk.raw --wglp /tmp/tmpd26pmi2h.glpk.glp --cpxlp
#  /tmp/tmph19x8588.pyomo.lp
# Reading problem data from '/tmp/tmph19x8588.pyomo.lp'...
# 1223 rows, 808 columns, 1802 non-zeros
# 6288 lines were read
# Writing problem data to '/tmp/tmpd26pmi2h.glpk.glp'...
# 5447 lines were written
# GLPK Simplex Optimizer, v4.65
# 1223 rows, 808 columns, 1802 non-zeros
# Preprocessing...
# 66 rows, 97 columns, 194 non-zeros
# Scaling...
#  A: min|aij| =  1.000e+00  max|aij| =  1.000e+00  ratio =  1.000e+00
# Problem data seem to be well scaled
# Constructing initial basis...
# Size of triangular part is 66
# *     0: obj =  -0.000000000e+00 inf =   0.000e+00 (28)
# *    50: obj =   1.925580000e+04 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# Time used:   0.0 secs
# Memory used: 0.8 Mb (825388 bytes)
# Writing basic solution to '/tmp/tmp6a5gt3uf.glpk.raw'...
# 2040 lines were written
# # ==========================================================
# # = Solver Results                                         =
# # ==========================================================
# # ----------------------------------------------------------
# #   Problem Information
# # ----------------------------------------------------------
# Problem:
# - Name: unknown
#   Lower bound: 19255.8
#   Upper bound: 19255.8
#   Number of objectives: 1
#   Number of constraints: 1223
#   Number of variables: 808
#   Number of nonzeros: 1802
#   Sense: maximize
# # ----------------------------------------------------------
# #   Solver Information
# # ----------------------------------------------------------
# Solver:
# - Status: ok
#   Termination condition: optimal
#   Statistics:
#     Branch and bound:
#       Number of bounded subproblems: 0
#       Number of created subproblems: 0
#   Error rc: 0
#   Time: 0.024865150451660156
# # ----------------------------------------------------------
# #   Solution Information
# # ----------------------------------------------------------
# Solution:
# - number of solutions: 1
#   number of solutions displayed: 1
# - Gap: 0.0
#   Status: feasible
#   Message: None
#   Objective:
#     Total_Profit_Objective:
#       Value: 19255.8
#   Variable:
#     SecondStageProfit:
#       Value: 19255.8
#     X[1]:
#       Value: 7.35
#     X[2]:
#       Value: 11.7
#     X[3]:
#       Value: 5.1
#     X[4]:
#       Value: 8.3
#     X[5]:
#       Value: 4.95
#     Y[1,11]:
#       Value: 1.5
#     Y[1,6]:
#       Value: 3.1
#     Y[1,7]:
#       Value: 0.9
#     Y[1,8]:
#       Value: 1.85
#     Y[10,14]:
#       Value: 2.1
#     Y[10,19]:
#       Value: 2
#     Y[11,15]:
#       Value: 3.8
#     Y[11,16]:
#       Value: 1.85
#     Y[12,15]:
#       Value: 1.85
#     Y[12,16]:
#       Value: 3.4
#     Y[12,17]:
#       Value: 1.75
#     Y[13,16]:
#       Value: 1.5
#     Y[13,17]:
#       Value: 4.65
#     Y[13,18]:
#       Value: 1.85
#     Y[14,17]:
#       Value: 2.05
#     Y[14,18]:
#       Value: 2.95
#     Y[14,19]:
#       Value: 1.1
#     Y[15,20]:
#       Value: 7.15
#     Y[16,20]:
#       Value: 9.9
#     Y[17,20]:
#       Value: 10.55
#     Y[18,20]:
#       Value: 6.7
#     Y[19,20]:
#       Value: 3.1
#     Y[2,11]:
#       Value: 2.9
#     Y[2,12]:
#       Value: 2.05
#     Y[2,6]:
#       Value: 1.25
#     Y[2,7]:
#       Value: 4.45
#     Y[2,8]:
#       Value: 1.05
#     Y[3,12]:
#       Value: 1.1
#     Y[3,7]:
#       Value: 0.9
#     Y[3,8]:
#       Value: 1.25
#     Y[3,9]:
#       Value: 1.85
#     Y[4,10]:
#       Value: 2.05
#     Y[4,13]:
#       Value: 2.1
#     Y[4,8]:
#       Value: 1.25
#     Y[4,9]:
#       Value: 2.9
#     Y[5,10]:
#       Value: 2.05
#     Y[5,14]:
#       Value: 2.9
#     Y[6,12]:
#       Value: 1.75
#     Y[6,15]:
#       Value: 1.5
#     Y[6,16]:
#       Value: 1.1
#     Y[7,11]:
#       Value: 1.25
#     Y[7,12]:
#       Value: 2.1
#     Y[7,13]:
#       Value: 2.9
#     Y[8,13]:
#       Value: 1.25
#     Y[8,16]:
#       Value: 2.05
#     Y[8,17]:
#       Value: 2.1
#     Y[9,13]:
#       Value: 1.75
#     Y[9,14]:
#       Value: 1.1
#     Y[9,18]:
#       Value: 1.9
#     Z[1,6]:
#       Value: 0.2
#     Z[10,19]:
#       Value: 1.1
#     Z[11,15]:
#       Value: 2.3
#     Z[12,16]:
#       Value: 2.5
#     Z[13,17]:
#       Value: 3.1
#     Z[14,18]:
#       Value: 1.7
#     Z[15,20]:
#       Value: 7.15
#     Z[16,20]:
#       Value: 9.9
#     Z[17,20]:
#       Value: 10.55
#     Z[18,20]:
#       Value: 6.7
#     Z[19,20]:
#       Value: 3.1
#     Z[2,7]:
#       Value: 2.9
#     Z[2,8]:
#       Value: 0.15
#     Z[9,18]:
#       Value: 0.15
#   Constraint: No values
# GLPSOL: GLPK LP/MIP Solver, v4.65
# Parameter(s) specified in the command line:
#  --write /tmp/tmp65giiyxp.glpk.raw --wglp /tmp/tmp5y53ycnd.glpk.glp --cpxlp
#  /tmp/tmp886frj0j.pyomo.lp
# Reading problem data from '/tmp/tmp886frj0j.pyomo.lp'...
# 1223 rows, 808 columns, 1802 non-zeros
# 6288 lines were read
# Writing problem data to '/tmp/tmp5y53ycnd.glpk.glp'...
# 5447 lines were written
# GLPK Simplex Optimizer, v4.65
# 1223 rows, 808 columns, 1802 non-zeros
# Preprocessing...
# 66 rows, 97 columns, 194 non-zeros
# Scaling...
#  A: min|aij| =  1.000e+00  max|aij| =  1.000e+00  ratio =  1.000e+00
# Problem data seem to be well scaled
# Constructing initial basis...
# Size of triangular part is 66
# *     0: obj =  -0.000000000e+00 inf =   0.000e+00 (28)
# *    50: obj =   1.925580000e+04 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# Time used:   0.0 secs
# Memory used: 0.8 Mb (825388 bytes)
# Writing basic solution to '/tmp/tmp65giiyxp.glpk.raw'...
# 2040 lines were written
# # ==========================================================
# # = Solver Results                                         =
# # ==========================================================
# # ----------------------------------------------------------
# #   Problem Information
# # ----------------------------------------------------------
# Problem:
# - Name: unknown
#   Lower bound: 19255.8
#   Upper bound: 19255.8
#   Number of objectives: 1
#   Number of constraints: 1223
#   Number of variables: 808
#   Number of nonzeros: 1802
#   Sense: maximize
# # ----------------------------------------------------------
# #   Solver Information
# # ----------------------------------------------------------
# Solver:
# - Status: ok
#   Termination condition: optimal
#   Statistics:
#     Branch and bound:
#       Number of bounded subproblems: 0
#       Number of created subproblems: 0
#   Error rc: 0
#   Time: 0.02169179916381836
# # ----------------------------------------------------------
# #   Solution Information
# # ----------------------------------------------------------
# Solution:
# - number of solutions: 1
#   number of solutions displayed: 1
# - Gap: 0.0
#   Status: feasible
#   Message: None
#   Objective:
#     Total_Profit_Objective:
#       Value: 19255.8
#   Variable:
#     SecondStageProfit:
#       Value: 19255.8
#     X[1]:
#       Value: 7.35
#     X[2]:
#       Value: 11.7
#     X[3]:
#       Value: 5.1
#     X[4]:
#       Value: 8.3
#     X[5]:
#       Value: 4.95
#     Y[1,11]:
#       Value: 1.5
#     Y[1,6]:
#       Value: 3.1
#     Y[1,7]:
#       Value: 0.9
#     Y[1,8]:
#       Value: 1.85
#     Y[10,14]:
#       Value: 2.1
#     Y[10,19]:
#       Value: 2
#     Y[11,15]:
#       Value: 3.8
#     Y[11,16]:
#       Value: 1.85
#     Y[12,15]:
#       Value: 1.85
#     Y[12,16]:
#       Value: 3.4
#     Y[12,17]:
#       Value: 1.75
#     Y[13,16]:
#       Value: 1.5
#     Y[13,17]:
#       Value: 4.65
#     Y[13,18]:
#       Value: 1.85
#     Y[14,17]:
#       Value: 2.05
#     Y[14,18]:
#       Value: 2.95
#     Y[14,19]:
#       Value: 1.1
#     Y[15,20]:
#       Value: 7.15
#     Y[16,20]:
#       Value: 9.9
#     Y[17,20]:
#       Value: 10.55
#     Y[18,20]:
#       Value: 6.7
#     Y[19,20]:
#       Value: 3.1
#     Y[2,11]:
#       Value: 2.9
#     Y[2,12]:
#       Value: 2.05
#     Y[2,6]:
#       Value: 1.25
#     Y[2,7]:
#       Value: 4.45
#     Y[2,8]:
#       Value: 1.05
#     Y[3,12]:
#       Value: 1.1
#     Y[3,7]:
#       Value: 0.9
#     Y[3,8]:
#       Value: 1.25
#     Y[3,9]:
#       Value: 1.85
#     Y[4,10]:
#       Value: 2.05
#     Y[4,13]:
#       Value: 2.1
#     Y[4,8]:
#       Value: 1.25
#     Y[4,9]:
#       Value: 2.9
#     Y[5,10]:
#       Value: 2.05
#     Y[5,14]:
#       Value: 2.9
#     Y[6,12]:
#       Value: 1.75
#     Y[6,15]:
#       Value: 1.5
#     Y[6,16]:
#       Value: 1.1
#     Y[7,11]:
#       Value: 1.25
#     Y[7,12]:
#       Value: 2.1
#     Y[7,13]:
#       Value: 2.9
#     Y[8,13]:
#       Value: 1.25
#     Y[8,16]:
#       Value: 2.05
#     Y[8,17]:
#       Value: 2.1
#     Y[9,13]:
#       Value: 1.75
#     Y[9,14]:
#       Value: 1.1
#     Y[9,18]:
#       Value: 1.9
#     Z[1,6]:
#       Value: 0.2
#     Z[10,19]:
#       Value: 1.1
#     Z[11,15]:
#       Value: 2.3
#     Z[12,16]:
#       Value: 2.5
#     Z[13,17]:
#       Value: 3.1
#     Z[14,18]:
#       Value: 1.7
#     Z[15,20]:
#       Value: 7.15
#     Z[16,20]:
#       Value: 9.9
#     Z[17,20]:
#       Value: 10.55
#     Z[18,20]:
#       Value: 6.7
#     Z[19,20]:
#       Value: 3.1
#     Z[2,7]:
#       Value: 2.9
#     Z[2,8]:
#       Value: 0.15
#     Z[9,18]:
#       Value: 0.15
#   Constraint: No values
# GLPSOL: GLPK LP/MIP Solver, v4.65
# Parameter(s) specified in the command line:
#  --write /tmp/tmpe5875vdq.glpk.raw --wglp /tmp/tmp_5abydwh.glpk.glp --cpxlp
#  /tmp/tmp14yugzv3.pyomo.lp
# Reading problem data from '/tmp/tmp14yugzv3.pyomo.lp'...
# 1223 rows, 808 columns, 1802 non-zeros
# 6288 lines were read
# Writing problem data to '/tmp/tmp_5abydwh.glpk.glp'...
# 5447 lines were written
# GLPK Simplex Optimizer, v4.65
# 1223 rows, 808 columns, 1802 non-zeros
# Preprocessing...
# 66 rows, 97 columns, 194 non-zeros
# Scaling...
#  A: min|aij| =  1.000e+00  max|aij| =  1.000e+00  ratio =  1.000e+00
# Problem data seem to be well scaled
# Constructing initial basis...
# Size of triangular part is 66
# *     0: obj =  -0.000000000e+00 inf =   0.000e+00 (28)
# *    50: obj =   1.925580000e+04 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# Time used:   0.0 secs
# Memory used: 0.8 Mb (825388 bytes)
# Writing basic solution to '/tmp/tmpe5875vdq.glpk.raw'...
# 2040 lines were written
# # ==========================================================
# # = Solver Results                                         =
# # ==========================================================
# # ----------------------------------------------------------
# #   Problem Information
# # ----------------------------------------------------------
# Problem:
# - Name: unknown
#   Lower bound: 19255.8
#   Upper bound: 19255.8
#   Number of objectives: 1
#   Number of constraints: 1223
#   Number of variables: 808
#   Number of nonzeros: 1802
#   Sense: maximize
# # ----------------------------------------------------------
# #   Solver Information
# # ----------------------------------------------------------
# Solver:
# - Status: ok
#   Termination condition: optimal
#   Statistics:
#     Branch and bound:
#       Number of bounded subproblems: 0
#       Number of created subproblems: 0
#   Error rc: 0
#   Time: 0.03241300582885742
# # ----------------------------------------------------------
# #   Solution Information
# # ----------------------------------------------------------
# Solution:
# - number of solutions: 1
#   number of solutions displayed: 1
# - Gap: 0.0
#   Status: feasible
#   Message: None
#   Objective:
#     Total_Profit_Objective:
#       Value: 19255.8
#   Variable:
#     SecondStageProfit:
#       Value: 19255.8
#     X[1]:
#       Value: 7.35
#     X[2]:
#       Value: 11.7
#     X[3]:
#       Value: 5.1
#     X[4]:
#       Value: 8.3
#     X[5]:
#       Value: 4.95
#     Y[1,11]:
#       Value: 1.5
#     Y[1,6]:
#       Value: 3.1
#     Y[1,7]:
#       Value: 0.9
#     Y[1,8]:
#       Value: 1.85
#     Y[10,14]:
#       Value: 2.1
#     Y[10,19]:
#       Value: 2
#     Y[11,15]:
#       Value: 3.8
#     Y[11,16]:
#       Value: 1.85
#     Y[12,15]:
#       Value: 1.85
#     Y[12,16]:
#       Value: 3.4
#     Y[12,17]:
#       Value: 1.75
#     Y[13,16]:
#       Value: 1.5
#     Y[13,17]:
#       Value: 4.65
#     Y[13,18]:
#       Value: 1.85
#     Y[14,17]:
#       Value: 2.05
#     Y[14,18]:
#       Value: 2.95
#     Y[14,19]:
#       Value: 1.1
#     Y[15,20]:
#       Value: 7.15
#     Y[16,20]:
#       Value: 9.9
#     Y[17,20]:
#       Value: 10.55
#     Y[18,20]:
#       Value: 6.7
#     Y[19,20]:
#       Value: 3.1
#     Y[2,11]:
#       Value: 2.9
#     Y[2,12]:
#       Value: 2.05
#     Y[2,6]:
#       Value: 1.25
#     Y[2,7]:
#       Value: 4.45
#     Y[2,8]:
#       Value: 1.05
#     Y[3,12]:
#       Value: 1.1
#     Y[3,7]:
#       Value: 0.9
#     Y[3,8]:
#       Value: 1.25
#     Y[3,9]:
#       Value: 1.85
#     Y[4,10]:
#       Value: 2.05
#     Y[4,13]:
#       Value: 2.1
#     Y[4,8]:
#       Value: 1.25
#     Y[4,9]:
#       Value: 2.9
#     Y[5,10]:
#       Value: 2.05
#     Y[5,14]:
#       Value: 2.9
#     Y[6,12]:
#       Value: 1.75
#     Y[6,15]:
#       Value: 1.5
#     Y[6,16]:
#       Value: 1.1
#     Y[7,11]:
#       Value: 1.25
#     Y[7,12]:
#       Value: 2.1
#     Y[7,13]:
#       Value: 2.9
#     Y[8,13]:
#       Value: 1.25
#     Y[8,16]:
#       Value: 2.05
#     Y[8,17]:
#       Value: 2.1
#     Y[9,13]:
#       Value: 1.75
#     Y[9,14]:
#       Value: 1.1
#     Y[9,18]:
#       Value: 1.9
#     Z[1,6]:
#       Value: 0.2
#     Z[10,19]:
#       Value: 1.1
#     Z[11,15]:
#       Value: 2.3
#     Z[12,16]:
#       Value: 2.5
#     Z[13,17]:
#       Value: 3.1
#     Z[14,18]:
#       Value: 1.7
#     Z[15,20]:
#       Value: 7.15
#     Z[16,20]:
#       Value: 9.9
#     Z[17,20]:
#       Value: 10.55
#     Z[18,20]:
#       Value: 6.7
#     Z[19,20]:
#       Value: 3.1
#     Z[2,7]:
#       Value: 2.9
#     Z[2,8]:
#       Value: 0.15
#     Z[9,18]:
#       Value: 0.15
#   Constraint: No values
# GLPSOL: GLPK LP/MIP Solver, v4.65
# Parameter(s) specified in the command line:
#  --write /tmp/tmp90w6edbc.glpk.raw --wglp /tmp/tmpz43qsvix.glpk.glp --cpxlp
#  /tmp/tmp6d53_kpi.pyomo.lp
# Reading problem data from '/tmp/tmp6d53_kpi.pyomo.lp'...
# 1223 rows, 808 columns, 1802 non-zeros
# 6288 lines were read
# Writing problem data to '/tmp/tmpz43qsvix.glpk.glp'...
# 5447 lines were written
# GLPK Simplex Optimizer, v4.65
# 1223 rows, 808 columns, 1802 non-zeros
# Preprocessing...
# 66 rows, 97 columns, 194 non-zeros
# Scaling...
#  A: min|aij| =  1.000e+00  max|aij| =  1.000e+00  ratio =  1.000e+00
# Problem data seem to be well scaled
# Constructing initial basis...
# Size of triangular part is 66
# *     0: obj =  -0.000000000e+00 inf =   0.000e+00 (28)
# *    50: obj =   1.925580000e+04 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# Time used:   0.0 secs
# Memory used: 0.8 Mb (825388 bytes)
# Writing basic solution to '/tmp/tmp90w6edbc.glpk.raw'...
# 2040 lines were written
# # ==========================================================
# # = Solver Results                                         =
# # ==========================================================
# # ----------------------------------------------------------
# #   Problem Information
# # ----------------------------------------------------------
# Problem:
# - Name: unknown
#   Lower bound: 19255.8
#   Upper bound: 19255.8
#   Number of objectives: 1
#   Number of constraints: 1223
#   Number of variables: 808
#   Number of nonzeros: 1802
#   Sense: maximize
# # ----------------------------------------------------------
# #   Solver Information
# # ----------------------------------------------------------
# Solver:
# - Status: ok
#   Termination condition: optimal
#   Statistics:
#     Branch and bound:
#       Number of bounded subproblems: 0
#       Number of created subproblems: 0
#   Error rc: 0
#   Time: 0.03169679641723633
# # ----------------------------------------------------------
# #   Solution Information
# # ----------------------------------------------------------
# Solution:
# - number of solutions: 1
#   number of solutions displayed: 1
# - Gap: 0.0
#   Status: feasible
#   Message: None
#   Objective:
#     Total_Profit_Objective:
#       Value: 19255.8
#   Variable:
#     SecondStageProfit:
#       Value: 19255.8
#     X[1]:
#       Value: 7.35
#     X[2]:
#       Value: 11.7
#     X[3]:
#       Value: 5.1
#     X[4]:
#       Value: 8.3
#     X[5]:
#       Value: 4.95
#     Y[1,11]:
#       Value: 1.5
#     Y[1,6]:
#       Value: 3.1
#     Y[1,7]:
#       Value: 0.9
#     Y[1,8]:
#       Value: 1.85
#     Y[10,14]:
#       Value: 2.1
#     Y[10,19]:
#       Value: 2
#     Y[11,15]:
#       Value: 3.8
#     Y[11,16]:
#       Value: 1.85
#     Y[12,15]:
#       Value: 1.85
#     Y[12,16]:
#       Value: 3.4
#     Y[12,17]:
#       Value: 1.75
#     Y[13,16]:
#       Value: 1.5
#     Y[13,17]:
#       Value: 4.65
#     Y[13,18]:
#       Value: 1.85
#     Y[14,17]:
#       Value: 2.05
#     Y[14,18]:
#       Value: 2.95
#     Y[14,19]:
#       Value: 1.1
#     Y[15,20]:
#       Value: 7.15
#     Y[16,20]:
#       Value: 9.9
#     Y[17,20]:
#       Value: 10.55
#     Y[18,20]:
#       Value: 6.7
#     Y[19,20]:
#       Value: 3.1
#     Y[2,11]:
#       Value: 2.9
#     Y[2,12]:
#       Value: 2.05
#     Y[2,6]:
#       Value: 1.25
#     Y[2,7]:
#       Value: 4.45
#     Y[2,8]:
#       Value: 1.05
#     Y[3,12]:
#       Value: 1.1
#     Y[3,7]:
#       Value: 0.9
#     Y[3,8]:
#       Value: 1.25
#     Y[3,9]:
#       Value: 1.85
#     Y[4,10]:
#       Value: 2.05
#     Y[4,13]:
#       Value: 2.1
#     Y[4,8]:
#       Value: 1.25
#     Y[4,9]:
#       Value: 2.9
#     Y[5,10]:
#       Value: 2.05
#     Y[5,14]:
#       Value: 2.9
#     Y[6,12]:
#       Value: 1.75
#     Y[6,15]:
#       Value: 1.5
#     Y[6,16]:
#       Value: 1.1
#     Y[7,11]:
#       Value: 1.25
#     Y[7,12]:
#       Value: 2.1
#     Y[7,13]:
#       Value: 2.9
#     Y[8,13]:
#       Value: 1.25
#     Y[8,16]:
#       Value: 2.05
#     Y[8,17]:
#       Value: 2.1
#     Y[9,13]:
#       Value: 1.75
#     Y[9,14]:
#       Value: 1.1
#     Y[9,18]:
#       Value: 1.9
#     Z[1,6]:
#       Value: 0.2
#     Z[10,19]:
#       Value: 1.1
#     Z[11,15]:
#       Value: 2.3
#     Z[12,16]:
#       Value: 2.5
#     Z[13,17]:
#       Value: 3.1
#     Z[14,18]:
#       Value: 1.7
#     Z[15,20]:
#       Value: 7.15
#     Z[16,20]:
#       Value: 9.9
#     Z[17,20]:
#       Value: 10.55
#     Z[18,20]:
#       Value: 6.7
#     Z[19,20]:
#       Value: 3.1
#     Z[2,7]:
#       Value: 2.9
#     Z[2,8]:
#       Value: 0.15
#     Z[9,18]:
#       Value: 0.15
#   Constraint: No values
# GLPSOL: GLPK LP/MIP Solver, v4.65
# Parameter(s) specified in the command line:
#  --write /tmp/tmpbi4s05gh.glpk.raw --wglp /tmp/tmpq1hy3aae.glpk.glp --cpxlp
#  /tmp/tmprcbucqxv.pyomo.lp
# Reading problem data from '/tmp/tmprcbucqxv.pyomo.lp'...
# 1223 rows, 808 columns, 1802 non-zeros
# 6288 lines were read
# Writing problem data to '/tmp/tmpq1hy3aae.glpk.glp'...
# 5447 lines were written
# GLPK Simplex Optimizer, v4.65
# 1223 rows, 808 columns, 1802 non-zeros
# Preprocessing...
# 66 rows, 97 columns, 194 non-zeros
# Scaling...
#  A: min|aij| =  1.000e+00  max|aij| =  1.000e+00  ratio =  1.000e+00
# Problem data seem to be well scaled
# Constructing initial basis...
# Size of triangular part is 66
# *     0: obj =  -0.000000000e+00 inf =   0.000e+00 (28)
# *    50: obj =   1.925580000e+04 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# Time used:   0.0 secs
# Memory used: 0.8 Mb (825388 bytes)
# Writing basic solution to '/tmp/tmpbi4s05gh.glpk.raw'...
# 2040 lines were written
# # ==========================================================
# # = Solver Results                                         =
# # ==========================================================
# # ----------------------------------------------------------
# #   Problem Information
# # ----------------------------------------------------------
# Problem:
# - Name: unknown
#   Lower bound: 19255.8
#   Upper bound: 19255.8
#   Number of objectives: 1
#   Number of constraints: 1223
#   Number of variables: 808
#   Number of nonzeros: 1802
#   Sense: maximize
# # ----------------------------------------------------------
# #   Solver Information
# # ----------------------------------------------------------
# Solver:
# - Status: ok
#   Termination condition: optimal
#   Statistics:
#     Branch and bound:
#       Number of bounded subproblems: 0
#       Number of created subproblems: 0
#   Error rc: 0
#   Time: 0.021869182586669922
# # ----------------------------------------------------------
# #   Solution Information
# # ----------------------------------------------------------
# Solution:
# - number of solutions: 1
#   number of solutions displayed: 1
# - Gap: 0.0
#   Status: feasible
#   Message: None
#   Objective:
#     Total_Profit_Objective:
#       Value: 19255.8
#   Variable:
#     SecondStageProfit:
#       Value: 19255.8
#     X[1]:
#       Value: 7.35
#     X[2]:
#       Value: 11.7
#     X[3]:
#       Value: 5.1
#     X[4]:
#       Value: 8.3
#     X[5]:
#       Value: 4.95
#     Y[1,11]:
#       Value: 1.5
#     Y[1,6]:
#       Value: 3.1
#     Y[1,7]:
#       Value: 0.9
#     Y[1,8]:
#       Value: 1.85
#     Y[10,14]:
#       Value: 2.1
#     Y[10,19]:
#       Value: 2
#     Y[11,15]:
#       Value: 3.8
#     Y[11,16]:
#       Value: 1.85
#     Y[12,15]:
#       Value: 1.85
#     Y[12,16]:
#       Value: 3.4
#     Y[12,17]:
#       Value: 1.75
#     Y[13,16]:
#       Value: 1.5
#     Y[13,17]:
#       Value: 4.65
#     Y[13,18]:
#       Value: 1.85
#     Y[14,17]:
#       Value: 2.05
#     Y[14,18]:
#       Value: 2.95
#     Y[14,19]:
#       Value: 1.1
#     Y[15,20]:
#       Value: 7.15
#     Y[16,20]:
#       Value: 9.9
#     Y[17,20]:
#       Value: 10.55
#     Y[18,20]:
#       Value: 6.7
#     Y[19,20]:
#       Value: 3.1
#     Y[2,11]:
#       Value: 2.9
#     Y[2,12]:
#       Value: 2.05
#     Y[2,6]:
#       Value: 1.25
#     Y[2,7]:
#       Value: 4.45
#     Y[2,8]:
#       Value: 1.05
#     Y[3,12]:
#       Value: 1.1
#     Y[3,7]:
#       Value: 0.9
#     Y[3,8]:
#       Value: 1.25
#     Y[3,9]:
#       Value: 1.85
#     Y[4,10]:
#       Value: 2.05
#     Y[4,13]:
#       Value: 2.1
#     Y[4,8]:
#       Value: 1.25
#     Y[4,9]:
#       Value: 2.9
#     Y[5,10]:
#       Value: 2.05
#     Y[5,14]:
#       Value: 2.9
#     Y[6,12]:
#       Value: 1.75
#     Y[6,15]:
#       Value: 1.5
#     Y[6,16]:
#       Value: 1.1
#     Y[7,11]:
#       Value: 1.25
#     Y[7,12]:
#       Value: 2.1
#     Y[7,13]:
#       Value: 2.9
#     Y[8,13]:
#       Value: 1.25
#     Y[8,16]:
#       Value: 2.05
#     Y[8,17]:
#       Value: 2.1
#     Y[9,13]:
#       Value: 1.75
#     Y[9,14]:
#       Value: 1.1
#     Y[9,18]:
#       Value: 1.9
#     Z[1,6]:
#       Value: 0.2
#     Z[10,19]:
#       Value: 1.1
#     Z[11,15]:
#       Value: 2.3
#     Z[12,16]:
#       Value: 2.5
#     Z[13,17]:
#       Value: 3.1
#     Z[14,18]:
#       Value: 1.7
#     Z[15,20]:
#       Value: 7.15
#     Z[16,20]:
#       Value: 9.9
#     Z[17,20]:
#       Value: 10.55
#     Z[18,20]:
#       Value: 6.7
#     Z[19,20]:
#       Value: 3.1
#     Z[2,7]:
#       Value: 2.9
#     Z[2,8]:
#       Value: 0.15
#     Z[9,18]:
#       Value: 0.15
#   Constraint: No values
# GLPSOL: GLPK LP/MIP Solver, v4.65
# Parameter(s) specified in the command line:
#  --write /tmp/tmpf9tachfo.glpk.raw --wglp /tmp/tmpzjx_c69a.glpk.glp --cpxlp
#  /tmp/tmpccrlg573.pyomo.lp
# Reading problem data from '/tmp/tmpccrlg573.pyomo.lp'...
# 1223 rows, 808 columns, 1802 non-zeros
# 6288 lines were read
# Writing problem data to '/tmp/tmpzjx_c69a.glpk.glp'...
# 5447 lines were written
# GLPK Simplex Optimizer, v4.65
# 1223 rows, 808 columns, 1802 non-zeros
# Preprocessing...
# 66 rows, 97 columns, 194 non-zeros
# Scaling...
#  A: min|aij| =  1.000e+00  max|aij| =  1.000e+00  ratio =  1.000e+00
# Problem data seem to be well scaled
# Constructing initial basis...
# Size of triangular part is 66
# *     0: obj =  -0.000000000e+00 inf =   0.000e+00 (28)
# *    50: obj =   1.925580000e+04 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# Time used:   0.0 secs
# Memory used: 0.8 Mb (825388 bytes)
# Writing basic solution to '/tmp/tmpf9tachfo.glpk.raw'...
# 2040 lines were written
# # ==========================================================
# # = Solver Results                                         =
# # ==========================================================
# # ----------------------------------------------------------
# #   Problem Information
# # ----------------------------------------------------------
# Problem:
# - Name: unknown
#   Lower bound: 19255.8
#   Upper bound: 19255.8
#   Number of objectives: 1
#   Number of constraints: 1223
#   Number of variables: 808
#   Number of nonzeros: 1802
#   Sense: maximize
# # ----------------------------------------------------------
# #   Solver Information
# # ----------------------------------------------------------
# Solver:
# - Status: ok
#   Termination condition: optimal
#   Statistics:
#     Branch and bound:
#       Number of bounded subproblems: 0
#       Number of created subproblems: 0
#   Error rc: 0
#   Time: 0.01973891258239746
# # ----------------------------------------------------------
# #   Solution Information
# # ----------------------------------------------------------
# Solution:
# - number of solutions: 1
#   number of solutions displayed: 1
# - Gap: 0.0
#   Status: feasible
#   Message: None
#   Objective:
#     Total_Profit_Objective:
#       Value: 19255.8
#   Variable:
#     SecondStageProfit:
#       Value: 19255.8
#     X[1]:
#       Value: 7.35
#     X[2]:
#       Value: 11.7
#     X[3]:
#       Value: 5.1
#     X[4]:
#       Value: 8.3
#     X[5]:
#       Value: 4.95
#     Y[1,11]:
#       Value: 1.5
#     Y[1,6]:
#       Value: 3.1
#     Y[1,7]:
#       Value: 0.9
#     Y[1,8]:
#       Value: 1.85
#     Y[10,14]:
#       Value: 2.1
#     Y[10,19]:
#       Value: 2
#     Y[11,15]:
#       Value: 3.8
#     Y[11,16]:
#       Value: 1.85
#     Y[12,15]:
#       Value: 1.85
#     Y[12,16]:
#       Value: 3.4
#     Y[12,17]:
#       Value: 1.75
#     Y[13,16]:
#       Value: 1.5
#     Y[13,17]:
#       Value: 4.65
#     Y[13,18]:
#       Value: 1.85
#     Y[14,17]:
#       Value: 2.05
#     Y[14,18]:
#       Value: 2.95
#     Y[14,19]:
#       Value: 1.1
#     Y[15,20]:
#       Value: 7.15
#     Y[16,20]:
#       Value: 9.9
#     Y[17,20]:
#       Value: 10.55
#     Y[18,20]:
#       Value: 6.7
#     Y[19,20]:
#       Value: 3.1
#     Y[2,11]:
#       Value: 2.9
#     Y[2,12]:
#       Value: 2.05
#     Y[2,6]:
#       Value: 1.25
#     Y[2,7]:
#       Value: 4.45
#     Y[2,8]:
#       Value: 1.05
#     Y[3,12]:
# ...
# Problem:
# - Name: unknown
#   Lower bound: 19255.8
#   Upper bound: 19255.8
#   Number of objectives: 1
#   Number of constraints: 1223
#   Number of variables: 808
#   Number of nonzeros: 1802
#   Sense: maximize
# # ----------------------------------------------------------
# #   Solver Information
# # ----------------------------------------------------------
# Solver:
# - Status: ok
#   Termination condition: optimal
#   Statistics:
#     Branch and bound:
#       Number of bounded subproblems: 0
#       Number of created subproblems: 0
#   Error rc: 0
#   Time: 0.02420496940612793
# # ----------------------------------------------------------
# #   Solution Information
# # ----------------------------------------------------------
# Solution:
# - number of solutions: 1
#   number of solutions displayed: 1
# - Gap: 0.0
#   Status: feasible
#   Message: None
#   Objective:
#     Total_Profit_Objective:
#       Value: 19255.8
#   Variable:
#     SecondStageProfit:
#       Value: 19255.8
#     X[1]:
#       Value: 7.35
#     X[2]:
#       Value: 11.7
#     X[3]:
#       Value: 5.1
#     X[4]:
#       Value: 8.3
#     X[5]:
#       Value: 4.95
#     Y[1,11]:
#       Value: 1.5
#     Y[1,6]:
#       Value: 3.1
#     Y[1,7]:
#       Value: 0.9
#     Y[1,8]:
#       Value: 1.85
#     Y[10,14]:
#       Value: 2.1
#     Y[10,19]:
#       Value: 2
#     Y[11,15]:
#       Value: 3.8
#     Y[11,16]:
#       Value: 1.85
#     Y[12,15]:
#       Value: 1.85
#     Y[12,16]:
#       Value: 3.4
#     Y[12,17]:
#       Value: 1.75
#     Y[13,16]:
#       Value: 1.5
#     Y[13,17]:
#       Value: 4.65
#     Y[13,18]:
#       Value: 1.85
#     Y[14,17]:
#       Value: 2.05
#     Y[14,18]:
#       Value: 2.95
#     Y[14,19]:
#       Value: 1.1
#     Y[15,20]:
#       Value: 7.15
#     Y[16,20]:
#       Value: 9.9
#     Y[17,20]:
#       Value: 10.55
#     Y[18,20]:
#       Value: 6.7
#     Y[19,20]:
#       Value: 3.1
#     Y[2,11]:
#       Value: 2.9
#     Y[2,12]:
#       Value: 2.05
#     Y[2,6]:
#       Value: 1.25
#     Y[2,7]:
#       Value: 4.45
#     Y[2,8]:
#       Value: 1.05
#     Y[3,12]:
#       Value: 1.1
#     Y[3,7]:
#       Value: 0.9
#     Y[3,8]:
#       Value: 1.25
#     Y[3,9]:
#       Value: 1.85
#     Y[4,10]:
#       Value: 2.05
#     Y[4,13]:
#       Value: 2.1
#     Y[4,8]:
#       Value: 1.25
#     Y[4,9]:
#       Value: 2.9
#     Y[5,10]:
#       Value: 2.05
#     Y[5,14]:
#       Value: 2.9
#     Y[6,12]:
#       Value: 1.75
#     Y[6,15]:
#       Value: 1.5
#     Y[6,16]:
#       Value: 1.1
#     Y[7,11]:
#       Value: 1.25
#     Y[7,12]:
#       Value: 2.1
#     Y[7,13]:
#       Value: 2.9
#     Y[8,13]:
#       Value: 1.25
#     Y[8,16]:
#       Value: 2.05
#     Y[8,17]:
#       Value: 2.1
#     Y[9,13]:
#       Value: 1.75
#     Y[9,14]:
#       Value: 1.1
#     Y[9,18]:
#       Value: 1.9
#     Z[1,6]:
#       Value: 0.2
#     Z[10,19]:
#       Value: 1.1
#     Z[11,15]:
#       Value: 2.3
#     Z[12,16]:
#       Value: 2.5
#     Z[13,17]:
#       Value: 3.1
#     Z[14,18]:
#       Value: 1.7
#     Z[15,20]:
#       Value: 7.15
#     Z[16,20]:
#       Value: 9.9
#     Z[17,20]:
#       Value: 10.55
#     Z[18,20]:
#       Value: 6.7
#     Z[19,20]:
#       Value: 3.1
#     Z[2,7]:
#       Value: 2.9
#     Z[2,8]:
#       Value: 0.15
#     Z[9,18]:
#       Value: 0.15
#   Constraint: No values
# GLPSOL: GLPK LP/MIP Solver, v4.65
# Parameter(s) specified in the command line:
#  --write /tmp/tmp5jcb6dz3.glpk.raw --wglp /tmp/tmp8ov9ha24.glpk.glp --cpxlp
#  /tmp/tmpofy7nh4s.pyomo.lp
# Reading problem data from '/tmp/tmpofy7nh4s.pyomo.lp'...
# 1223 rows, 808 columns, 1802 non-zeros
# 6288 lines were read
# Writing problem data to '/tmp/tmp8ov9ha24.glpk.glp'...
# 5447 lines were written
# GLPK Simplex Optimizer, v4.65
# 1223 rows, 808 columns, 1802 non-zeros
# Preprocessing...
# 66 rows, 97 columns, 194 non-zeros
# Scaling...
#  A: min|aij| =  1.000e+00  max|aij| =  1.000e+00  ratio =  1.000e+00
# Problem data seem to be well scaled
# Constructing initial basis...
# Size of triangular part is 66
# *     0: obj =  -0.000000000e+00 inf =   0.000e+00 (28)
# *    50: obj =   1.925580000e+04 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# Time used:   0.0 secs
# Memory used: 0.8 Mb (825388 bytes)
# Writing basic solution to '/tmp/tmp5jcb6dz3.glpk.raw'...
# 2040 lines were written
# # ==========================================================
# # = Solver Results                                         =
# # ==========================================================
# # ----------------------------------------------------------
# #   Problem Information
# # ----------------------------------------------------------
# Problem:
# - Name: unknown
#   Lower bound: 19255.8
#   Upper bound: 19255.8
#   Number of objectives: 1
#   Number of constraints: 1223
#   Number of variables: 808
#   Number of nonzeros: 1802
#   Sense: maximize
# # ----------------------------------------------------------
# #   Solver Information
# # ----------------------------------------------------------
# Solver:
# - Status: ok
#   Termination condition: optimal
#   Statistics:
#     Branch and bound:
#       Number of bounded subproblems: 0
#       Number of created subproblems: 0
#   Error rc: 0
#   Time: 0.026497364044189453
# # ----------------------------------------------------------
# #   Solution Information
# # ----------------------------------------------------------
# Solution:
# - number of solutions: 1
#   number of solutions displayed: 1
# - Gap: 0.0
#   Status: feasible
#   Message: None
#   Objective:
#     Total_Profit_Objective:
#       Value: 19255.8
#   Variable:
#     SecondStageProfit:
#       Value: 19255.8
#     X[1]:
#       Value: 7.35
#     X[2]:
#       Value: 11.7
#     X[3]:
#       Value: 5.1
#     X[4]:
#       Value: 8.3
#     X[5]:
#       Value: 4.95
#     Y[1,11]:
#       Value: 1.5
#     Y[1,6]:
#       Value: 3.1
#     Y[1,7]:
#       Value: 0.9
#     Y[1,8]:
#       Value: 1.85
#     Y[10,14]:
#       Value: 2.1
#     Y[10,19]:
#       Value: 2
#     Y[11,15]:
#       Value: 3.8
#     Y[11,16]:
#       Value: 1.85
#     Y[12,15]:
#       Value: 1.85
#     Y[12,16]:
#       Value: 3.4
#     Y[12,17]:
#       Value: 1.75
#     Y[13,16]:
#       Value: 1.5
#     Y[13,17]:
#       Value: 4.65
#     Y[13,18]:
#       Value: 1.85
#     Y[14,17]:
#       Value: 2.05
#     Y[14,18]:
#       Value: 2.95
#     Y[14,19]:
#       Value: 1.1
#     Y[15,20]:
#       Value: 7.15
#     Y[16,20]:
#       Value: 9.9
#     Y[17,20]:
#       Value: 10.55
#     Y[18,20]:
#       Value: 6.7
#     Y[19,20]:
#       Value: 3.1
#     Y[2,11]:
#       Value: 2.9
#     Y[2,12]:
#       Value: 2.05
#     Y[2,6]:
#       Value: 1.25
#     Y[2,7]:
#       Value: 4.45
#     Y[2,8]:
#       Value: 1.05
#     Y[3,12]:
#       Value: 1.1
#     Y[3,7]:
#       Value: 0.9
#     Y[3,8]:
#       Value: 1.25
#     Y[3,9]:
#       Value: 1.85
#     Y[4,10]:
#       Value: 2.05
#     Y[4,13]:
#       Value: 2.1
#     Y[4,8]:
#       Value: 1.25
#     Y[4,9]:
#       Value: 2.9
#     Y[5,10]:
#       Value: 2.05
#     Y[5,14]:
#       Value: 2.9
#     Y[6,12]:
#       Value: 1.75
#     Y[6,15]:
#       Value: 1.5
#     Y[6,16]:
#       Value: 1.1
#     Y[7,11]:
#       Value: 1.25
#     Y[7,12]:
#       Value: 2.1
#     Y[7,13]:
#       Value: 2.9
#     Y[8,13]:
#       Value: 1.25
#     Y[8,16]:
#       Value: 2.05
#     Y[8,17]:
#       Value: 2.1
#     Y[9,13]:
#       Value: 1.75
#     Y[9,14]:
#       Value: 1.1
#     Y[9,18]:
#       Value: 1.9
#     Z[1,6]:
#       Value: 0.2
#     Z[10,19]:
#       Value: 1.1
#     Z[11,15]:
#       Value: 2.3
#     Z[12,16]:
#       Value: 2.5
#     Z[13,17]:
#       Value: 3.1
#     Z[14,18]:
#       Value: 1.7
#     Z[15,20]:
#       Value: 7.15
#     Z[16,20]:
#       Value: 9.9
#     Z[17,20]:
#       Value: 10.55
#     Z[18,20]:
#       Value: 6.7
#     Z[19,20]:
#       Value: 3.1
#     Z[2,7]:
#       Value: 2.9
#     Z[2,8]:
#       Value: 0.15
#     Z[9,18]:
#       Value: 0.15
#   Constraint: No values
# GLPSOL: GLPK LP/MIP Solver, v4.65
# Parameter(s) specified in the command line:
#  --write /tmp/tmpn0fs1naj.glpk.raw --wglp /tmp/tmp5vehvw71.glpk.glp --cpxlp
#  /tmp/tmpzpoak0zs.pyomo.lp
# Reading problem data from '/tmp/tmpzpoak0zs.pyomo.lp'...
# 1223 rows, 808 columns, 1802 non-zeros
# 6288 lines were read
# Writing problem data to '/tmp/tmp5vehvw71.glpk.glp'...
# 5447 lines were written
# GLPK Simplex Optimizer, v4.65
# 1223 rows, 808 columns, 1802 non-zeros
# Preprocessing...
# 66 rows, 97 columns, 194 non-zeros
# Scaling...
#  A: min|aij| =  1.000e+00  max|aij| =  1.000e+00  ratio =  1.000e+00
# Problem data seem to be well scaled
# Constructing initial basis...
# Size of triangular part is 66
# *     0: obj =  -0.000000000e+00 inf =   0.000e+00 (28)
# *    50: obj =   1.925580000e+04 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# Time used:   0.0 secs
# Memory used: 0.8 Mb (825388 bytes)
# Writing basic solution to '/tmp/tmpn0fs1naj.glpk.raw'...
# 2040 lines were written
# # ==========================================================
# # = Solver Results                                         =
# # ==========================================================
# # ----------------------------------------------------------
# #   Problem Information
# # ----------------------------------------------------------
# Problem:
# - Name: unknown
#   Lower bound: 19255.8
#   Upper bound: 19255.8
#   Number of objectives: 1
#   Number of constraints: 1223
#   Number of variables: 808
#   Number of nonzeros: 1802
#   Sense: maximize
# # ----------------------------------------------------------
# #   Solver Information
# # ----------------------------------------------------------
# Solver:
# - Status: ok
#   Termination condition: optimal
#   Statistics:
#     Branch and bound:
#       Number of bounded subproblems: 0
#       Number of created subproblems: 0
#   Error rc: 0
#   Time: 0.024111032485961914
# # ----------------------------------------------------------
# #   Solution Information
# # ----------------------------------------------------------
# Solution:
# - number of solutions: 1
#   number of solutions displayed: 1
# - Gap: 0.0
#   Status: feasible
#   Message: None
#   Objective:
#     Total_Profit_Objective:
#       Value: 19255.8
#   Variable:
#     SecondStageProfit:
#       Value: 19255.8
#     X[1]:
#       Value: 7.35
#     X[2]:
#       Value: 11.7
#     X[3]:
#       Value: 5.1
#     X[4]:
#       Value: 8.3
#     X[5]:
#       Value: 4.95
#     Y[1,11]:
#       Value: 1.5
#     Y[1,6]:
#       Value: 3.1
#     Y[1,7]:
#       Value: 0.9
#     Y[1,8]:
#       Value: 1.85
#     Y[10,14]:
#       Value: 2.1
#     Y[10,19]:
#       Value: 2
#     Y[11,15]:
#       Value: 3.8
#     Y[11,16]:
#       Value: 1.85
#     Y[12,15]:
#       Value: 1.85
#     Y[12,16]:
#       Value: 3.4
#     Y[12,17]:
#       Value: 1.75
#     Y[13,16]:
#       Value: 1.5
#     Y[13,17]:
#       Value: 4.65
#     Y[13,18]:
#       Value: 1.85
#     Y[14,17]:
#       Value: 2.05
#     Y[14,18]:
#       Value: 2.95
#     Y[14,19]:
#       Value: 1.1
#     Y[15,20]:
#       Value: 7.15
#     Y[16,20]:
#       Value: 9.9
#     Y[17,20]:
#       Value: 10.55
#     Y[18,20]:
#       Value: 6.7
#     Y[19,20]:
#       Value: 3.1
#     Y[2,11]:
#       Value: 2.9
#     Y[2,12]:
#       Value: 2.05
#     Y[2,6]:
#       Value: 1.25
#     Y[2,7]:
#       Value: 4.45
#     Y[2,8]:
#       Value: 1.05
#     Y[3,12]:
#       Value: 1.1
#     Y[3,7]:
#       Value: 0.9
#     Y[3,8]:
#       Value: 1.25
#     Y[3,9]:
#       Value: 1.85
#     Y[4,10]:
#       Value: 2.05
#     Y[4,13]:
#       Value: 2.1
#     Y[4,8]:
#       Value: 1.25
#     Y[4,9]:
#       Value: 2.9
#     Y[5,10]:
#       Value: 2.05
#     Y[5,14]:
#       Value: 2.9
#     Y[6,12]:
#       Value: 1.75
#     Y[6,15]:
#       Value: 1.5
#     Y[6,16]:
#       Value: 1.1
#     Y[7,11]:
#       Value: 1.25
#     Y[7,12]:
#       Value: 2.1
#     Y[7,13]:
#       Value: 2.9
#     Y[8,13]:
#       Value: 1.25
#     Y[8,16]:
#       Value: 2.05
#     Y[8,17]:
#       Value: 2.1
#     Y[9,13]:
#       Value: 1.75
#     Y[9,14]:
#       Value: 1.1
#     Y[9,18]:
#       Value: 1.9
#     Z[1,6]:
#       Value: 0.2
#     Z[10,19]:
#       Value: 1.1
#     Z[11,15]:
#       Value: 2.3
#     Z[12,16]:
#       Value: 2.5
#     Z[13,17]:
#       Value: 3.1
#     Z[14,18]:
#       Value: 1.7
#     Z[15,20]:
#       Value: 7.15
#     Z[16,20]:
#       Value: 9.9
#     Z[17,20]:
#       Value: 10.55
#     Z[18,20]:
#       Value: 6.7
#     Z[19,20]:
#       Value: 3.1
#     Z[2,7]:
#       Value: 2.9
#     Z[2,8]:
#       Value: 0.15
#     Z[9,18]:
#       Value: 0.15
#   Constraint: No values
# GLPSOL: GLPK LP/MIP Solver, v4.65
# Parameter(s) specified in the command line:
#  --write /tmp/tmpifs7mjr_.glpk.raw --wglp /tmp/tmp4sqpbw9j.glpk.glp --cpxlp
#  /tmp/tmp5eqt4cwq.pyomo.lp
# Reading problem data from '/tmp/tmp5eqt4cwq.pyomo.lp'...
# 1223 rows, 808 columns, 1802 non-zeros
# 6288 lines were read
# Writing problem data to '/tmp/tmp4sqpbw9j.glpk.glp'...
# 5447 lines were written
# GLPK Simplex Optimizer, v4.65
# 1223 rows, 808 columns, 1802 non-zeros
# Preprocessing...
# 66 rows, 97 columns, 194 non-zeros
# Scaling...
#  A: min|aij| =  1.000e+00  max|aij| =  1.000e+00  ratio =  1.000e+00
# Problem data seem to be well scaled
# Constructing initial basis...
# Size of triangular part is 66
# *     0: obj =  -0.000000000e+00 inf =   0.000e+00 (28)
# *    50: obj =   1.925580000e+04 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# Time used:   0.0 secs
# Memory used: 0.8 Mb (825388 bytes)
# Writing basic solution to '/tmp/tmpifs7mjr_.glpk.raw'...
# 2040 lines were written
# # ==========================================================
# # = Solver Results                                         =
# # ==========================================================
# # ----------------------------------------------------------
# #   Problem Information
# # ----------------------------------------------------------
# Problem:
# - Name: unknown
#   Lower bound: 19255.8
#   Upper bound: 19255.8
#   Number of objectives: 1
#   Number of constraints: 1223
#   Number of variables: 808
#   Number of nonzeros: 1802
#   Sense: maximize
# # ----------------------------------------------------------
# #   Solver Information
# # ----------------------------------------------------------
# Solver:
# - Status: ok
#   Termination condition: optimal
#   Statistics:
#     Branch and bound:
#       Number of bounded subproblems: 0
#       Number of created subproblems: 0
#   Error rc: 0
#   Time: 0.029318809509277344
# # ----------------------------------------------------------
# #   Solution Information
# # ----------------------------------------------------------
# Solution:
# - number of solutions: 1
#   number of solutions displayed: 1
# - Gap: 0.0
#   Status: feasible
#   Message: None
#   Objective:
#     Total_Profit_Objective:
#       Value: 19255.8
#   Variable:
#     SecondStageProfit:
#       Value: 19255.8
#     X[1]:
#       Value: 7.35
#     X[2]:
#       Value: 11.7
#     X[3]:
#       Value: 5.1
#     X[4]:
#       Value: 8.3
#     X[5]:
#       Value: 4.95
#     Y[1,11]:
#       Value: 1.5
#     Y[1,6]:
#       Value: 3.1
#     Y[1,7]:
#       Value: 0.9
#     Y[1,8]:
#       Value: 1.85
#     Y[10,14]:
#       Value: 2.1
#     Y[10,19]:
#       Value: 2
#     Y[11,15]:
#       Value: 3.8
#     Y[11,16]:
#       Value: 1.85
#     Y[12,15]:
#       Value: 1.85
#     Y[12,16]:
#       Value: 3.4
#     Y[12,17]:
#       Value: 1.75
#     Y[13,16]:
#       Value: 1.5
#     Y[13,17]:
#       Value: 4.65
#     Y[13,18]:
#       Value: 1.85
#     Y[14,17]:
#       Value: 2.05
#     Y[14,18]:
#       Value: 2.95
#     Y[14,19]:
#       Value: 1.1
#     Y[15,20]:
#       Value: 7.15
#     Y[16,20]:
#       Value: 9.9
#     Y[17,20]:
#       Value: 10.55
#     Y[18,20]:
#       Value: 6.7
#     Y[19,20]:
#       Value: 3.1
#     Y[2,11]:
#       Value: 2.9
#     Y[2,12]:
#       Value: 2.05
#     Y[2,6]:
#       Value: 1.25
#     Y[2,7]:
#       Value: 4.45
#     Y[2,8]:
#       Value: 1.05
#     Y[3,12]:
#       Value: 1.1
#     Y[3,7]:
#       Value: 0.9
#     Y[3,8]:
#       Value: 1.25
#     Y[3,9]:
#       Value: 1.85
#     Y[4,10]:
#       Value: 2.05
#     Y[4,13]:
#       Value: 2.1
#     Y[4,8]:
#       Value: 1.25
#     Y[4,9]:
#       Value: 2.9
#     Y[5,10]:
#       Value: 2.05
#     Y[5,14]:
#       Value: 2.9
#     Y[6,12]:
#       Value: 1.75
#     Y[6,15]:
#       Value: 1.5
#     Y[6,16]:
#       Value: 1.1
#     Y[7,11]:
#       Value: 1.25
#     Y[7,12]:
#       Value: 2.1
#     Y[7,13]:
#       Value: 2.9
#     Y[8,13]:
#       Value: 1.25
#     Y[8,16]:
#       Value: 2.05
#     Y[8,17]:
#       Value: 2.1
#     Y[9,13]:
#       Value: 1.75
#     Y[9,14]:
#       Value: 1.1
#     Y[9,18]:
#       Value: 1.9
#     Z[1,6]:
#       Value: 0.2
#     Z[10,19]:
#       Value: 1.1
#     Z[11,15]:
#       Value: 2.3
#     Z[12,16]:
#       Value: 2.5
#     Z[13,17]:
#       Value: 3.1
#     Z[14,18]:
#       Value: 1.7
#     Z[15,20]:
#       Value: 7.15
#     Z[16,20]:
#       Value: 9.9
#     Z[17,20]:
#       Value: 10.55
#     Z[18,20]:
#       Value: 6.7
#     Z[19,20]:
#       Value: 3.1
#     Z[2,7]:
#       Value: 2.9
#     Z[2,8]:
#       Value: 0.15
#     Z[9,18]:
#       Value: 0.15
#   Constraint: No values
